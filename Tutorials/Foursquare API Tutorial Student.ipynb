# %% [markdown]
# # FourSquare API Tutorial
# ### Jordan Ireland

# %%
## install a few things we may need. This may take a few minutes
# !pip install ipywidgets python-decouple
# !jupyter labextension install @jupyter-widgets/jupyterlab-manager
# !jupyter nbextension enable --py widgetsnbextension
# Out:
# Requirement already satisfied: ipywidgets in c:\users\pandu\anaconda3\lib\site-packages (7.5.1)
# Collecting python-decouple
#   Downloading https://files.pythonhosted.org/packages/c7/82/dd20cdca396f58be86c6e710a3958f4a34ca98c5dd3989ee978b6cb9f97e/python-decouple-3.3.tar.gz
# Requirement already satisfied: ipython>=4.0.0; python_version >= "3.3" in c:\users\pandu\anaconda3\lib\site-packages (from ipywidgets) (7.7.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\pandu\anaconda3\lib\site-packages (from ipywidgets) (3.5.0)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\pandu\anaconda3\lib\site-packages (from ipywidgets) (5.1.1)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\pandu\anaconda3\lib\site-packages (from ipywidgets) (4.3.2)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\pandu\anaconda3\lib\site-packages (from ipywidgets) (4.4.0)
# Requirement already satisfied: pygments in c:\users\pandu\anaconda3\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (2.4.2)
# Requirement already satisfied: jedi>=0.10 in c:\users\pandu\anaconda3\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (0.13.3)
# Requirement already satisfied: setuptools>=18.5 in c:\users\pandu\appdata\roaming\python\python37\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (41.2.0)
# Requirement already satisfied: backcall in c:\users\pandu\anaconda3\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (0.1.0)
# Requirement already satisfied: colorama; sys_platform == "win32" in c:\users\pandu\anaconda3\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (0.4.1)
# Requirement already satisfied: pickleshare in c:\users\pandu\anaconda3\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (0.7.5)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in c:\users\pandu\anaconda3\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (2.0.9)
# Requirement already satisfied: decorator in c:\users\pandu\anaconda3\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (4.4.0)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\pandu\anaconda3\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets) (6.0.0)
# Requirement already satisfied: jupyter-client in c:\users\pandu\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (5.3.1)
# Requirement already satisfied: tornado>=4.2 in c:\users\pandu\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (6.0.3)
# Requirement already satisfied: ipython-genutils in c:\users\pandu\anaconda3\lib\site-packages (from traitlets>=4.3.1->ipywidgets) (0.2.0)
# Requirement already satisfied: six in c:\users\pandu\anaconda3\lib\site-packages (from traitlets>=4.3.1->ipywidgets) (1.12.0)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\users\pandu\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets) (3.0.1)
# Requirement already satisfied: jupyter-core in c:\users\pandu\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets) (4.5.0)
# Requirement already satisfied: parso>=0.3.0 in c:\users\pandu\anaconda3\lib\site-packages (from jedi>=0.10->ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (0.5.0)
# Requirement already satisfied: wcwidth in c:\users\pandu\anaconda3\lib\site-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (0.1.7)
# Requirement already satisfied: jinja2 in c:\users\pandu\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (2.10.1)
# Requirement already satisfied: nbconvert in c:\users\pandu\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (5.5.0)
# Requirement already satisfied: terminado>=0.8.1 in c:\users\pandu\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.8.2)
# Requirement already satisfied: prometheus-client in c:\users\pandu\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.7.1)
# Requirement already satisfied: Send2Trash in c:\users\pandu\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (1.5.0)
# Requirement already satisfied: pyzmq>=17 in c:\users\pandu\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (18.0.0)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\pandu\anaconda3\lib\site-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets) (2.8.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\pandu\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets) (19.1.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\pandu\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets) (0.14.11)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\pandu\anaconda3\lib\site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (1.1.1)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\pandu\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.3)
# Requirement already satisfied: defusedxml in c:\users\pandu\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.6.0)
# Requirement already satisfied: bleach in c:\users\pandu\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (3.1.0)
# Requirement already satisfied: testpath in c:\users\pandu\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.4.2)
# Requirement already satisfied: mistune>=0.8.1 in c:\users\pandu\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.8.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\pandu\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (1.4.2)
# Requirement already satisfied: webencodings in c:\users\pandu\anaconda3\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.5.1)
# Building wheels for collected packages: python-decouple
#   Building wheel for python-decouple (setup.py): started
#   Building wheel for python-decouple (setup.py): finished with status 'done'
#   Created wheel for python-decouple: filename=python_decouple-3.3-cp37-none-any.whl size=9034 sha256=7e2d09389a06971167a9364e6195600c841b009244ae5fd273f77a7376dfa8b4
#   Stored in directory: C:\Users\pandu\AppData\Local\pip\Cache\wheels\f4\9b\79\5eec9ea205382552b014e749cb8a2b4ce0d6836a6f4db5ac0c
# Successfully built python-decouple
# Installing collected packages: python-decouple
# Successfully installed python-decouple-3.3
# WARNING: You are using pip version 19.2.3, however version 19.3.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.
# An error occured.
# RuntimeError: JupyterLab failed to build
# See the log file for details:  C:\Users\pandu\AppData\Local\Temp\jupyterlab-debug-sakcc7rs.log
# Building jupyterlab assets
# Enabling notebook extension jupyter-js-widgets/extension...
#       - Validating: ok

# %% [markdown]
# #### What are we doing up there?
# **ipywidgets** makes your notebooks interactable by allowing you to add forms, sliders, buttons, etc. They're a little in depth, but I will cover the basics here! \
# The next few lines allows them to work inside Jupyter Labs. I don't know how they work, but they work!
#
# **decouple** is a way to keep secret codes and keys from being exposed. Github will ignore them so they won't be uploaded and adds some security to python. \
# In order to use it. You have to make a `.env` file inside of your base directory for that project. (.env is the full file name. Make sure there are no spaces before it).
# I will go over this later on.
#
# ### Make a Foursquare Developer Account
# [Sign up for Foursquare](https://foursquare.com/developers/signup)
#
# Click `Create New App`, Name it whatever you want! I'm naming my 'Foursquare API Tutorial'. The website can be your portfolio link!
#
# ![appsetup.png](appsetup.png)
#
# #### Once you're done, don't share your Client ID or Client Secret with anyone.

# %% [markdown]
# ## Creating some basic widgets to get the values we want

# %%
## import things we need
import ipywidgets as widgets
import requests
import pandas as pd
import numpy as np
from decouple import config

## Create class so ipywidgets can update values after running the cell
class Updated:

    def __init__(self, city, radius, r_type):
        self.city_value = city
        self.radius_value = radius
        self.type_value = r_type

    def update(self, city, radius, r_type) -> None:
        self.city_value = city.value
        self.radius_value = radius.value
        self.type_value = r_type.value

## Create widgets so we can interact with the API
city_input = widgets.Dropdown(
    options=['Phoenix', 'Chicago', 'San Diego', 'New York City']
)
type_input = widgets.Dropdown(
    options= [('BBQ Joint', '4bf58dd8d48988d1df931735'), ('American', '4bf58dd8d48988d14e941735'), ('Asian', '4bf58dd8d48988d142941735')]
)
radius_input = widgets.IntSlider(
    value=50000,
    min=1000,
    max=100000,
    step=250,
    description='Range:',
    continuous_update=False,
    orientation='horizontal'
)
button = widgets.Button(description="Submit")
output = widgets.Output()

## Make function for buttom being clicked
def on_button_clicked(b):
    with output:
        query.update(city_input, radius_input, type_input)

button.on_click(on_button_clicked)
display(city_input, radius_input, type_input, button, output)

## Make a new class with default values
query = Updated(city_input.value, radius_input.value, type_input.value)

## URL to foursquare's API
URL = 'https://api.foursquare.com/v2/venues/search'
# Out:
# Dropdown(options=('Phoenix', 'Chicago', 'San Diego', 'New York City'), value='Phoenix')
# IntSlider(value=50000, continuous_update=False, description='Range:', max=100000, min=1000, step=250)
# Dropdown(options=(('BBQ Joint', '4bf58dd8d48988d1df931735'), ('American', '4bf58dd8d48988d14e941735'), ('Asian…
# Button(description='Submit', style=ButtonStyle())
# Output()

# %% [markdown]
# ## Calling the API

# %% [markdown]
# An API GET request is broken into a few things.
# * The base URL, in this case it's `https://api.foursquare.com/v2/venues/search`
# * The query string. A query string is a list of variables and values that are set by the API you're using. [View Foursquares API Variables](https://developer.foursquare.com/docs/api/venues/search) If you see, there are a few required ones. `ll` OR `near`. The others are optional. How do we use them?
#  * After the base url, you need to add a `?`. That tells the browser where the actual request starts with custom variables.
#    * `https://api.foursquare.com/v2/venues/search?`
#  * Enter your first Variable
#    * `https://api.foursquare.com/v2/venues/search?near=Chicago`
#  * Separate your variables with a `&`.
#    * `https://api.foursquare.com/v2/venues/search?near=Chicago&radius=25000`
#
# That's a lot of work for 1 request. Luckily requests has a parameter! \
# First you have to make a dictionary with all the values you want. `'near':'Chicago'` is the same as above!
#
# Lets put it into practice

# %%
## Make a new dictionary for Python's request GET
PARAMS = {'near':query.city_value, 'radius':query.radius_value, 'categoryId':query.type_value, 'client_id':config('CLIENT_ID'), 'client_secret':config('CLIENT_SEC'), 'v':'20180412'} 

## sending get request and saving the response as response object 
r = requests.get(url = URL, params = PARAMS) 

## extracting data in json format
response = r.json()

## This is what we get from the API
response
# Out:
# {'meta': {'code': 200, 'requestId': '5dd814d3ad1ab4001b672682'},
#  'response': {'venues': [{'id': '5b3717439deb7d0039e963a1',
#     'name': 'Rudy\'s "Country Store" and Bar-B-Q',
#     'contact': {},
#     'location': {'address': '1733 N Higley Rd',
#      'lat': 33.3814058,
#      'lng': -111.7210321,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.3814058,
#        'lng': -111.7210321}],
#      'postalCode': '85234',
#      'cc': 'US',
#      'city': 'Gilbert',
#      'state': 'AZ',
#      'country': 'United States',
#      'formattedAddress': ['1733 N Higley Rd',
#       'Gilbert, AZ 85234',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1df931735',
#       'name': 'BBQ Joint',
#       'pluralName': 'BBQ Joints',
#       'shortName': 'BBQ',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': False,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#     'referralId': 'v-1574442202',
#     'venueChains': [],
#     'hasPerk': False},
#    {'id': '59ebb9133ba767222d4df282',
#     'name': 'Manna BBQ',
#     'contact': {},
#     'location': {'address': '1135 S Dobson Rd',
#      'lat': 33.39453826397179,
#      'lng': -111.87310353456627,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.39453826397179,
#        'lng': -111.87310353456627}],
#      'postalCode': '85202',
#      'cc': 'US',
#      'city': 'Mesa',
#      'state': 'AZ',
#      'country': 'United States',
#      'formattedAddress': ['1135 S Dobson Rd',
#       'Mesa, AZ 85202',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d113941735',
#       'name': 'Korean Restaurant',
#       'pluralName': 'Korean Restaurants',
#       'shortName': 'Korean',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/korean_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': False,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#     'referralId': 'v-1574442202',
#     'venueChains': [],
#     'hasPerk': False},
#    {'id': '588e25d613bb774f534556d2',
#     'name': 'Bonfire Grill',
#     'contact': {},
#     'location': {'lat': 33.639405665497,
#      'lng': -112.39015117391732,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.639405665497,
#        'lng': -112.39015117391732}],
#      'cc': 'US',
#      'city': 'Surprise',
#      'state': 'AZ',
#      'country': 'United States',
#      'formattedAddress': ['Surprise, AZ', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d14e941735',
#       'name': 'American Restaurant',
#       'pluralName': 'American Restaurants',
#       'shortName': 'American',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': False,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#     'referralId': 'v-1574442202',
#     'venueChains': [],
#     'hasPerk': False},
#    {'id': '5a0e3bd6a4ba7c5f7f0a8000',
#     'name': 'Dickeys Barbecue Pit',
#     'contact': {},
#     'location': {'address': '10005 W McDowell Rd Ste 101',
#      'crossStreet': '99th Avenue',
#      'lat': 33.46432015943471,
#      'lng': -112.27502656715075,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.46432015943471,
#        'lng': -112.27502656715075}],
#      'postalCode': '85392',
#      'cc': 'US',
#      'city': 'Avondale',
#      'state': 'AZ',
#      'country': 'United States',
#      'formattedAddress': ['10005 W McDowell Rd Ste 101 (99th Avenue)',
#       'Avondale, AZ 85392',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1df931735',
#       'name': 'BBQ Joint',
#       'pluralName': 'BBQ Joints',
#       'shortName': 'BBQ',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': True,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'delivery': {'id': '1386896',
#      'url': 'https://www.grubhub.com/restaurant/dickeys-barbecue-pit-10005-w-mcdowell-rd-ste-101-avondale/1386896?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1386896',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#     'referralId': 'v-1574442202',
#     'venueChains': [],
#     'hasPerk': False},
#    {'id': '5bf47e1f3149b9002c04e905',
#     'name': 'Little Miss Bbq - Sunnyslope',
#     'contact': {},
#     'location': {'address': '8901 N 7th St',
#      'crossStreet': 'Townley Avenue',
#      'lat': 33.566267178238746,
#      'lng': -112.06485021285314,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.566267178238746,
#        'lng': -112.06485021285314}],
#      'postalCode': '85020',
#      'cc': 'US',
#      'city': 'Phoenix',
#      'state': 'AZ',
#      'country': 'United States',
#      'formattedAddress': ['8901 N 7th St (Townley Avenue)',
#       'Phoenix, AZ 85020',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1df931735',
#       'name': 'BBQ Joint',
#       'pluralName': 'BBQ Joints',
#       'shortName': 'BBQ',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': False,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#     'referralId': 'v-1574442202',
#     'venueChains': [],
#     'hasPerk': False},
#    {'id': '5b92b9b89411f2002c5fbdc2',
#     'name': 'Caldwell County BBQ',
#     'contact': {},
#     'location': {'address': '18324 E Nunneley Rd',
#      'crossStreet': 'Power Road',
#      'lat': 33.332632,
#      'lng': -111.688314,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.332632,
#        'lng': -111.688314}],
#      'postalCode': '85296',
#      'cc': 'US',
#      'city': 'Gilbert',
#      'state': 'AZ',
#      'country': 'United States',
#      'formattedAddress': ['18324 E Nunneley Rd (Power Road)',
#       'Gilbert, AZ 85296',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1df931735',
#       'name': 'BBQ Joint',
#       'pluralName': 'BBQ Joints',
#       'shortName': 'BBQ',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': False,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'delivery': {'id': '1290770',
#      'url': 'https://www.grubhub.com/restaurant/caldwell-county-bbq-18324-e-nunneley-rd-gilbert/1290770?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1290770',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#     'referralId': 'v-1574442202',
#     'venueChains': [],
#     'hasPerk': False},
#    {'id': '5980bf389be522267d8064c2',
#     'name': "Bobby Q's 32Nd",
#     'contact': {},
#     'location': {'address': '3154 E Camelback Rd',
#      'crossStreet': '32nd Street St at Camelback Road',
#      'lat': 33.51132219271709,
#      'lng': -112.0136493416997,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.51132219271709,
#        'lng': -112.0136493416997}],
#      'postalCode': '85016',
#      'cc': 'US',
#      'city': 'Phoenix',
#      'state': 'AZ',
#      'country': 'United States',
#      'formattedAddress': ['3154 E Camelback Rd (32nd Street St at Camelback Road)',
#       'Phoenix, AZ 85016',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1df931735',
#       'name': 'BBQ Joint',
#       'pluralName': 'BBQ Joints',
#       'shortName': 'BBQ',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': False,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#     'referralId': 'v-1574442202',
#     'venueChains': [],
#     'hasPerk': False},
#    {'id': '5a7e4eee49281456574a4103',
#     'name': 'Starlite Bbq Scottsdale',
#     'contact': {},
#     'location': {'address': '7620 E Indian School Rd Ste 101',
#      'crossStreet': 'Miller',
#      'lat': 33.49674138533633,
#      'lng': -111.91706836459258,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.49674138533633,
#        'lng': -111.91706836459258}],
#      'postalCode': '85251',
#      'cc': 'US',
#      'city': 'Scottsdale',
#      'state': 'AZ',
#      'country': 'United States',
#      'formattedAddress': ['7620 E Indian School Rd Ste 101 (Miller)',
#       'Scottsdale, AZ 85251',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1df931735',
#       'name': 'BBQ Joint',
#       'pluralName': 'BBQ Joints',
#       'shortName': 'BBQ',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': True,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'delivery': {'id': '727555',
#      'url': 'https://www.grubhub.com/restaurant/starlite-bbq-7620-e-indian-school-rd-ste-101-scottsdale/727555?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=727555',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'venuePage': {'id': '532169275'},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#     'referralId': 'v-1574442202',
#     'venueChains': [],
#     'hasPerk': False},
#    {'id': '5ab183f2a2c00b1507214a97',
#     'name': 'Ono Hawaiian Bbq',
#     'contact': {},
#     'location': {'lat': 33.639509,
#      'lng': -112.358569,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.639509,
#        'lng': -112.358569}],
#      'postalCode': '85374',
#      'cc': 'US',
#      'city': 'Surprise',
#      'state': 'AZ',
#      'country': 'United States',
#      'formattedAddress': ['Surprise, AZ 85374', 'United States']},
#     'categories': [{'id': '52e81612bcbc57f1066b79fe',
#       'name': 'Hawaiian Restaurant',
#       'pluralName': 'Hawaiian Restaurants',
#       'shortName': 'Hawaiian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': False,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#     'referralId': 'v-1574442202',
#     'venueChains': [],
#     'hasPerk': False},
#    {'id': '56ad4003498ead73d5f7a071',
#     'name': 'Pork On A Fork',
#     'contact': {},
#     'location': {'address': '1949 E Camelback Rd',
#      'lat': 33.50744886769579,
#      'lng': -112.0407058007533,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.50744886769579,
#        'lng': -112.0407058007533}],
#      'postalCode': '85016',
#      'cc': 'US',
#      'city': 'Phoenix',
#      'state': 'AZ',
#      'country': 'United States',
#      'formattedAddress': ['1949 E Camelback Rd',
#       'Phoenix, AZ 85016',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1df931735',
#       'name': 'BBQ Joint',
#       'pluralName': 'BBQ Joints',
#       'shortName': 'BBQ',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': False,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'delivery': {'id': '327356',
#      'url': 'https://www.grubhub.com/restaurant/pork-on-a-fork-1949-e-camelback-rd-ste-140-phoenix/327356?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=327356',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#     'referralId': 'v-1574442202',
#     'venueChains': [],
#     'hasPerk': False},
#    {'id': '538e8e80498e69d6e8360b6a',
#     'name': "Rudy's BBQ",
#     'contact': {},
#     'location': {'address': '845 N Litchfield Rd',
#      'crossStreet': 'at W Test Dr',
#      'lat': 33.4555637361808,
#      'lng': -112.3575907945633,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.4555637361808,
#        'lng': -112.3575907945633}],
#      'postalCode': '85338',
#      'cc': 'US',
#      'city': 'Goodyear',
#      'state': 'AZ',
#      'country': 'United States',
#      'formattedAddress': ['845 N Litchfield Rd (at W Test Dr)',
#       'Goodyear, AZ 85338',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1df931735',
#       'name': 'BBQ Joint',
#       'pluralName': 'BBQ Joints',
#       'shortName': 'BBQ',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': False,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#     'referralId': 'v-1574442202',
#     'venueChains': [],
#     'hasPerk': False},
#    {'id': '4eec58b70039cff10434513d',
#     'name': 'Rudy’s Country Store & Bar-B-Q',
#     'contact': {},
#     'location': {'address': '7300 W Chandler Blvd',
#      'crossStreet': 'at 54th St',
#      'lat': 33.305738986253985,
#      'lng': -111.96753054857248,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.305738986253985,
#        'lng': -111.96753054857248}],
#      'postalCode': '85226',
#      'cc': 'US',
#      'city': 'Chandler',
#      'state': 'AZ',
#      'country': 'United States',
#      'formattedAddress': ['7300 W Chandler Blvd (at 54th St)',
#       'Chandler, AZ 85226',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1df931735',
#       'name': 'BBQ Joint',
#       'pluralName': 'BBQ Joints',
#       'shortName': 'BBQ',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': True,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'delivery': {'id': '1322047',
#      'url': 'https://www.grubhub.com/restaurant/rudys-bbq-7300-west-chandler-boulevard-chandler/1322047?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1322047',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#     'referralId': 'v-1574442202',
#     'venueChains': [],
#     'hasPerk': False},
#    {'id': '4afe4c5af964a5201e2f22e3',
#     'name': "Dillon's KC BBQ Arrowhead",
#     'contact': {},
#     'location': {'address': '20585 N 59th Ave',
#      'lat': 33.67215103350895,
#      'lng': -112.18631885981868,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.67215103350895,
#        'lng': -112.18631885981868}],
#      'postalCode': '85308',
#      'cc': 'US',
#      'city': 'Glendale',
#      'state': 'AZ',
#      'country': 'United States',
#      'formattedAddress': ['20585 N 59th Ave',
#       'Glendale, AZ 85308',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1df931735',
#       'name': 'BBQ Joint',
#       'pluralName': 'BBQ Joints',
#       'shortName': 'BBQ',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': True,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#     'referralId': 'v-1574442202',
#     'venueChains': [],
#     'hasPerk': False},
#    {'id': '4b47f95ef964a5207b4526e3',
#     'name': 'Handlebar J',
#     'contact': {},
#     'location': {'address': '7116 E Becker Ln',
#      'crossStreet': 'at 71st Pl.',
#      'lat': 33.58314,
#      'lng': -111.92751,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.58314,
#        'lng': -111.92751}],
#      'postalCode': '85254',
#      'cc': 'US',
#      'city': 'Scottsdale',
#      'state': 'AZ',
#      'country': 'United States',
#      'formattedAddress': ['7116 E Becker Ln (at 71st Pl.)',
#       'Scottsdale, AZ 85254',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'shortName': 'Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': False,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#     'referralId': 'v-1574442202',
#     'venueChains': [],
#     'hasPerk': False},
#    {'id': '4a6b6c35f964a520b3ce1fe3',
#     'name': "Famous Dave's Bar-B-Que",
#     'contact': {},
#     'location': {'address': '1011 N Dobson Rd',
#      'crossStreet': 'at Mesa Riverview Dr',
#      'lat': 33.43550462216282,
#      'lng': -111.86913453782229,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.43550462216282,
#        'lng': -111.86913453782229}],
#      'postalCode': '85201',
#      'cc': 'US',
#      'city': 'Mesa',
#      'state': 'AZ',
#      'country': 'United States',
#      'formattedAddress': ['1011 N Dobson Rd (at Mesa Riverview Dr)',
#       'Mesa, AZ 85201',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1df931735',
#       'name': 'BBQ Joint',
#       'pluralName': 'BBQ Joints',
#       'shortName': 'BBQ',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': True,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'delivery': {'id': '1278727',
#      'url': 'https://www.grubhub.com/restaurant/famous-daves-1011-n-dobson-rd-mesa/1278727?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1278727',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#     'referralId': 'v-1574442202',
#     'venueChains': [],
#     'hasPerk': False},
#    {'id': '4283ee00f964a520ec221fe3',
#     'name': "Joe's Real BBQ",
#     'contact': {},
#     'location': {'address': '301 N Gilbert Rd',
#      'crossStreet': 'at E Page Ave',
#      'lat': 33.355038,
#      'lng': -111.789396,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.355038,
#        'lng': -111.789396}],
#      'postalCode': '85234',
#      'cc': 'US',
#      'city': 'Gilbert',
#      'state': 'AZ',
#      'country': 'United States',
#      'formattedAddress': ['301 N Gilbert Rd (at E Page Ave)',
#       'Gilbert, AZ 85234',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1df931735',
#       'name': 'BBQ Joint',
#       'pluralName': 'BBQ Joints',
#       'shortName': 'BBQ',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': True,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'venuePage': {'id': '42383346'},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#     'referralId': 'v-1574442202',
#     'venueChains': [],
#     'hasPerk': False},
#    {'id': '4a3c61d2f964a52077a11fe3',
#     'name': 'TEXAZ Grill',
#     'contact': {},
#     'location': {'address': '6003 N 16th St',
#      'crossStreet': '16th St & Bethany Home Rd.',
#      'lat': 33.523906521704646,
#      'lng': -112.04723802657821,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.523906521704646,
#        'lng': -112.04723802657821}],
#      'postalCode': '85016',
#      'cc': 'US',
#      'city': 'Phoenix',
#      'state': 'AZ',
#      'country': 'United States',
#      'formattedAddress': ['6003 N 16th St (16th St & Bethany Home Rd.)',
#       'Phoenix, AZ 85016',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d14f941735',
#       'name': 'Southern / Soul Food Restaurant',
#       'pluralName': 'Southern / Soul Food Restaurants',
#       'shortName': 'Southern / Soul',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/southern_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': True,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'venuePage': {'id': '119551655'},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#     'referralId': 'v-1574442202',
#     'venueChains': [],
#     'hasPerk': False},
#    {'id': '52fe57a6498e9c8170bcb97a',
#     'name': 'Little Miss BBQ',
#     'contact': {},
#     'location': {'address': '4301 E University Dr',
#      'crossStreet': 'btwn S 42nd & S 44th St',
#      'lat': 33.421608492944095,
#      'lng': -111.98909416794777,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.421608492944095,
#        'lng': -111.98909416794777}],
#      'postalCode': '85034',
#      'cc': 'US',
#      'city': 'Phoenix',
#      'state': 'AZ',
#      'country': 'United States',
#      'formattedAddress': ['4301 E University Dr (btwn S 42nd & S 44th St)',
#       'Phoenix, AZ 85034',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1df931735',
#       'name': 'BBQ Joint',
#       'pluralName': 'BBQ Joints',
#       'shortName': 'BBQ',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': True,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'venuePage': {'id': '207741164'},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#     'referralId': 'v-1574442202',
#     'venueChains': [],
#     'hasPerk': False},
#    {'id': '4a7a3435f964a520d7e81fe3',
#     'name': 'Bandera Restaurant',
#     'contact': {},
#     'location': {'address': '3821 N Scottsdale Rd',
#      'lat': 33.492336312995825,
#      'lng': -111.9260077746243,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.492336312995825,
#        'lng': -111.9260077746243}],
#      'postalCode': '85251',
#      'cc': 'US',
#      'city': 'Scottsdale',
#      'state': 'AZ',
#      'country': 'United States',
#      'formattedAddress': ['3821 N Scottsdale Rd',
#       'Scottsdale, AZ 85251',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d14e941735',
#       'name': 'American Restaurant',
#       'pluralName': 'American Restaurants',
#       'shortName': 'American',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': True,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#     'referralId': 'v-1574442202',
#     'venueChains': [],
#     'hasPerk': False},
#    {'id': '4ba0f63df964a520748a37e3',
#     'name': 'The Pork Shop',
#     'contact': {},
#     'location': {'address': '3359 E Combs Rd',
#      'crossStreet': 'Combs and Schnepf',
#      'lat': 33.219825316851164,
#      'lng': -111.52978953497652,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.219825316851164,
#        'lng': -111.52978953497652}],
#      'postalCode': '85140',
#      'cc': 'US',
#      'city': 'Queen Creek',
#      'state': 'AZ',
#      'country': 'United States',
#      'formattedAddress': ['3359 E Combs Rd (Combs and Schnepf)',
#       'Queen Creek, AZ 85140',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d11d951735',
#       'name': 'Butcher',
#       'pluralName': 'Butchers',
#       'shortName': 'Butcher',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_butcher_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': False,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#     'referralId': 'v-1574442202',
#     'venueChains': [],
#     'hasPerk': False},
#    {'id': '4a7bc3dff964a520c4eb1fe3',
#     'name': 'Saddle Ranch Chop House',
#     'contact': {},
#     'location': {'address': '9375 W Coyotes Blvd',
#      'crossStreet': 'in Westgate Entertainment District',
#      'lat': 33.53322122783963,
#      'lng': -112.26112966254742,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.53322122783963,
#        'lng': -112.26112966254742}],
#      'postalCode': '85305',
#      'cc': 'US',
#      'city': 'Glendale',
#      'state': 'AZ',
#      'country': 'United States',
#      'formattedAddress': ['9375 W Coyotes Blvd (in Westgate Entertainment District)',
#       'Glendale, AZ 85305',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1df931735',
#       'name': 'BBQ Joint',
#       'pluralName': 'BBQ Joints',
#       'shortName': 'BBQ',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': False,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'delivery': {'id': '1002935',
#      'url': 'https://www.grubhub.com/restaurant/saddle-ranch-chop-house---glendale-az-9375-w-coyotes-blvd-glendale/1002935?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1002935',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#     'referralId': 'v-1574442202',
#     'venueChains': [],
#     'hasPerk': False},
#    {'id': '4283ee00f964a520eb221fe3',
#     'name': "Famous Dave's Bar-B-Que",
#     'contact': {},
#     'location': {'address': '3250 W Frye Rd',
#      'crossStreet': 'at Chandler Fashion Square',
#      'lat': 33.29821769522356,
#      'lng': -111.89845469520722,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.29821769522356,
#        'lng': -111.89845469520722}],
#      'postalCode': '85226',
#      'cc': 'US',
#      'city': 'Chandler',
#      'state': 'AZ',
#      'country': 'United States',
#      'formattedAddress': ['3250 W Frye Rd (at Chandler Fashion Square)',
#       'Chandler, AZ 85226',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1df931735',
#       'name': 'BBQ Joint',
#       'pluralName': 'BBQ Joints',
#       'shortName': 'BBQ',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': True,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'delivery': {'id': '1278811',
#      'url': 'https://www.grubhub.com/restaurant/famous-daves-3250-w-frye-rd-chandler/1278811?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1278811',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#     'referralId': 'v-1574442202',
#     'venueChains': [],
#     'hasPerk': False},
#    {'id': '4b302880f964a52013f724e3',
#     'name': "Bobby-Q's Restaurant",
#     'contact': {},
#     'location': {'address': '8501 N 27th Ave',
#      'crossStreet': 'Northern',
#      'lat': 33.56104974722998,
#      'lng': -112.11584116058451,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.56104974722998,
#        'lng': -112.11584116058451}],
#      'postalCode': '85051',
#      'cc': 'US',
#      'neighborhood': 'North Mountain',
#      'city': 'Phoenix',
#      'state': 'AZ',
#      'country': 'United States',
#      'formattedAddress': ['8501 N 27th Ave (Northern)',
#       'Phoenix, AZ 85051',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1df931735',
#       'name': 'BBQ Joint',
#       'pluralName': 'BBQ Joints',
#       'shortName': 'BBQ',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': True,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'delivery': {'id': '848861',
#      'url': 'https://www.grubhub.com/restaurant/bobby-q-8501-n-27th-ave-phoenix/848861?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=848861',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'venuePage': {'id': '42571449'},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#     'referralId': 'v-1574442202',
#     'venueChains': [],
#     'hasPerk': False},
#    {'id': '4aac61a2f964a520b75d20e3',
#     'name': "Lucille's Smokehouse Bar-B-Que",
#     'contact': {},
#     'location': {'address': '2030 E Rio Salado Pkwy',
#      'crossStreet': 'at Tempe Marketplace',
#      'lat': 33.43364064865639,
#      'lng': -111.9038656147827,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.43364064865639,
#        'lng': -111.9038656147827}],
#      'postalCode': '85281',
#      'cc': 'US',
#      'city': 'Tempe',
#      'state': 'AZ',
#      'country': 'United States',
#      'formattedAddress': ['2030 E Rio Salado Pkwy (at Tempe Marketplace)',
#       'Tempe, AZ 85281',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1df931735',
#       'name': 'BBQ Joint',
#       'pluralName': 'BBQ Joints',
#       'shortName': 'BBQ',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': True,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'delivery': {'id': '1283309',
#      'url': 'https://www.grubhub.com/restaurant/lucilles-smokehouse-bar-b-que-2030-e-rio-salado-pkwy-tempe/1283309?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1283309',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#     'referralId': 'v-1574442202',
#     'venueChains': [],
#     'hasPerk': False},
#    {'id': '4e9de76c2c5b8638e59a1899',
#     'name': "Dillon's KC BBQ at Wildlife World Zoo",
#     'contact': {},
#     'location': {'address': '16335 W Northern Ave',
#      'lat': 33.55000124622615,
#      'lng': -112.41066366434097,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.55000124622615,
#        'lng': -112.41066366434097}],
#      'postalCode': '85340',
#      'cc': 'US',
#      'neighborhood': 'Wildlife World Zoo',
#      'city': 'Litchfield Park',
#      'state': 'AZ',
#      'country': 'United States',
#      'formattedAddress': ['16335 W Northern Ave',
#       'Litchfield Park, AZ 85340',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1df931735',
#       'name': 'BBQ Joint',
#       'pluralName': 'BBQ Joints',
#       'shortName': 'BBQ',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': True,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#     'referralId': 'v-1574442202',
#     'venueChains': [],
#     'hasPerk': False},
#    {'id': '5296680511d2c99c7ecff0e0',
#     'name': 'Bootleggers Modern American Smokehouse',
#     'contact': {},
#     'location': {'address': '7217 E 1st St',
#      'crossStreet': 'at Scottsdale Rd',
#      'lat': 33.4919730431969,
#      'lng': -111.92550735398822,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.4919730431969,
#        'lng': -111.92550735398822}],
#      'postalCode': '85251',
#      'cc': 'US',
#      'city': 'Scottsdale',
#      'state': 'AZ',
#      'country': 'United States',
#      'formattedAddress': ['7217 E 1st St (at Scottsdale Rd)',
#       'Scottsdale, AZ 85251',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d14e941735',
#       'name': 'American Restaurant',
#       'pluralName': 'American Restaurants',
#       'shortName': 'American',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': True,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'delivery': {'id': '632792',
#      'url': 'https://www.grubhub.com/restaurant/bootleggers-smokehouse-7217-e-1st-st-scottsdale/632792?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=632792',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#     'referralId': 'v-1574442202',
#     'venueChains': [],
#     'hasPerk': False},
#    {'id': '566c68da498efdbbe27dddd5',
#     'name': "Dillon's Bayou at Pleasant Harbor",
#     'contact': {},
#     'location': {'address': '40202 87th Ave.',
#      'lat': 33.85144940384647,
#      'lng': -112.25834302044416,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.85144940384647,
#        'lng': -112.25834302044416}],
#      'postalCode': '85383',
#      'cc': 'US',
#      'city': 'Peoria',
#      'state': 'AZ',
#      'country': 'United States',
#      'formattedAddress': ['40202 87th Ave.',
#       'Peoria, AZ 85383',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1df931735',
#       'name': 'BBQ Joint',
#       'pluralName': 'BBQ Joints',
#       'shortName': 'BBQ',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': True,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'venuePage': {'id': '532008495'},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#     'referralId': 'v-1574442202',
#     'venueChains': [],
#     'hasPerk': False},
#    {'id': '4b29a633f964a5201ba224e3',
#     'name': 'Ono Hawaiian BBQ',
#     'contact': {},
#     'location': {'address': '13070 W Rancho Santa Fe Blvd',
#      'crossStreet': 'at N Dysart Rd',
#      'lat': 33.46127205723772,
#      'lng': -112.33973422401174,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.46127205723772,
#        'lng': -112.33973422401174}],
#      'postalCode': '85392',
#      'cc': 'US',
#      'city': 'Avondale',
#      'state': 'AZ',
#      'country': 'United States',
#      'formattedAddress': ['13070 W Rancho Santa Fe Blvd (at N Dysart Rd)',
#       'Avondale, AZ 85392',
#       'United States']},
#     'categories': [{'id': '52e81612bcbc57f1066b79fe',
#       'name': 'Hawaiian Restaurant',
#       'pluralName': 'Hawaiian Restaurants',
#       'shortName': 'Hawaiian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': False,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#     'referralId': 'v-1574442202',
#     'venueChains': [],
#     'hasPerk': False},
#    {'id': '4b36693df964a520d03425e3',
#     'name': 'Horny Toad',
#     'contact': {},
#     'location': {'address': '6738 E Cave Creek Rd',
#      'crossStreet': 'North Of E Viola Ln.',
#      'lat': 33.83316040367466,
#      'lng': -111.93499085181664,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.83316040367466,
#        'lng': -111.93499085181664}],
#      'postalCode': '85331',
#      'cc': 'US',
#      'city': 'Cave Creek',
#      'state': 'AZ',
#      'country': 'United States',
#      'formattedAddress': ['6738 E Cave Creek Rd (North Of E Viola Ln.)',
#       'Cave Creek, AZ 85331',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1df931735',
#       'name': 'BBQ Joint',
#       'pluralName': 'BBQ Joints',
#       'shortName': 'BBQ',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': False,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#     'referralId': 'v-1574442202',
#     'venueChains': [],
#     'hasPerk': False},
#    {'id': '5383a021498e31b16470e518',
#     'name': 'Angry Crab Shack and BBQ',
#     'contact': {},
#     'location': {'address': '2808 E Indian School Rd',
#      'lat': 33.496210719523205,
#      'lng': -112.02122835932173,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.496210719523205,
#        'lng': -112.02122835932173}],
#      'postalCode': '85016',
#      'cc': 'US',
#      'city': 'Phoenix',
#      'state': 'AZ',
#      'country': 'United States',
#      'formattedAddress': ['2808 E Indian School Rd',
#       'Phoenix, AZ 85016',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ce941735',
#       'name': 'Seafood Restaurant',
#       'pluralName': 'Seafood Restaurants',
#       'shortName': 'Seafood',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/seafood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': True,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'venuePage': {'id': '97543239'},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#     'referralId': 'v-1574442202',
#     'venueChains': [],
#     'hasPerk': False}],
#   'confident': False,
#   'geocode': {'what': '',
#    'where': 'phoenix',
#    'feature': {'cc': 'US',
#     'name': 'Phoenix',
#     'displayName': 'Phoenix, AZ, United States',
#     'matchedName': 'Phoenix, AZ, United States',
#     'highlightedName': '<b>Phoenix</b>, AZ, United States',
#     'woeType': 7,
#     'slug': 'phoenix-arizona',
#     'id': 'geonameid:5308655',
#     'longId': '72057594043236591',
#     'geometry': {'center': {'lat': 33.44838, 'lng': -112.07404},
#      'bounds': {'ne': {'lat': 33.918391, 'lng': -111.92541},
#       'sw': {'lat': 33.290259999999996, 'lng': -112.324065}}}},
#    'parents': []}}}

# %% [markdown]
# ## Breaking down the response

# %%
print(f"Meta: {response['meta']}")
print(f"Response Code: {response['meta']['code']}")
print(f"Request ID: {response['meta']['requestId']}")
# Out:
# Meta: {'code': 200, 'requestId': '5dd80f0d71782e001be79141'}
# Response Code: 200
# Request ID: 5dd80f0d71782e001be79141

# %% [markdown]
# * Meta is the metadata from the API response. It tells you about the call
# * The response code is what happened during the call. Code 200 usually means that the resquest for information was successful and there weren't any errors. This **doesn't** mean you got the data you wanted. Just that it didn't fail
# * Most APIs give you a request ID that you can look up (through another API call to a separate endpoint), to look up more information.
#
# If you want to see Foursquares Codes, go [here](https://developer.foursquare.com/docs/api/troubleshooting/errors)
#
# To view a pretty version or the JSON file at anytime, view the [example tree](https://codebeautify.org/jsonviewer/cb8187b7)

# %%
## This is what we really care about
data = response['response']
data
# Out:
# {'venues': [{'id': '51bd1640498e9a4f3c67a5c8',
#    'name': 'Gaslamp BBQ',
#    'contact': {},
#    'location': {'address': '524 Island Ave',
#     'lat': 32.710492957951836,
#     'lng': -117.15982530474932,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 32.710492957951836,
#       'lng': -117.15982530474932}],
#     'postalCode': '92101',
#     'cc': 'US',
#     'neighborhood': 'Gaslamp',
#     'city': 'San Diego',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['524 Island Ave',
#      'San Diego, CA 92101',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d116941735',
#      'name': 'Bar',
#      'pluralName': 'Bars',
#      'shortName': 'Bar',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#       'suffix': '.png'},
#      'primary': True}],
#    'verified': True,
#    'stats': {'tipCount': 0,
#     'usersCount': 0,
#     'checkinsCount': 0,
#     'visitsCount': 0},
#    'beenHere': {'count': 0,
#     'lastCheckinExpiredAt': 0,
#     'marked': False,
#     'unconfirmedCount': 0},
#    'venuePage': {'id': '83375008'},
#    'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#    'referralId': 'v-1574440731',
#    'venueChains': [],
#    'hasPerk': False},
#   {'id': '5203ccf0498e4458881c39d3',
#    'name': "Phil's BBQ",
#    'contact': {},
#    'location': {'address': 'Terminal 2',
#     'crossStreet': 'at SAN Airport',
#     'lat': 32.73398500762943,
#     'lng': -117.20422302549987,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 32.73398500762943,
#       'lng': -117.20422302549987}],
#     'postalCode': '92110',
#     'cc': 'US',
#     'city': 'San Diego',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['Terminal 2 (at SAN Airport)',
#      'San Diego, CA 92110',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1df931735',
#      'name': 'BBQ Joint',
#      'pluralName': 'BBQ Joints',
#      'shortName': 'BBQ',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#       'suffix': '.png'},
#      'primary': True}],
#    'verified': False,
#    'stats': {'tipCount': 0,
#     'usersCount': 0,
#     'checkinsCount': 0,
#     'visitsCount': 0},
#    'beenHere': {'count': 0,
#     'lastCheckinExpiredAt': 0,
#     'marked': False,
#     'unconfirmedCount': 0},
#    'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#    'referralId': 'v-1574440731',
#    'venueChains': [],
#    'hasPerk': False},
#   {'id': '460d2cfcf964a52002451fe3',
#    'name': "Phil's BBQ",
#    'contact': {},
#    'location': {'address': '3740 Sports Arena Blvd',
#     'crossStreet': 'at Hancock St.',
#     'lat': 32.75482013180317,
#     'lng': -117.21582764351203,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 32.75482013180317,
#       'lng': -117.21582764351203}],
#     'postalCode': '92110',
#     'cc': 'US',
#     'city': 'San Diego',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['3740 Sports Arena Blvd (at Hancock St.)',
#      'San Diego, CA 92110',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1df931735',
#      'name': 'BBQ Joint',
#      'pluralName': 'BBQ Joints',
#      'shortName': 'BBQ',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#       'suffix': '.png'},
#      'primary': True}],
#    'verified': False,
#    'stats': {'tipCount': 0,
#     'usersCount': 0,
#     'checkinsCount': 0,
#     'visitsCount': 0},
#    'beenHere': {'count': 0,
#     'lastCheckinExpiredAt': 0,
#     'marked': False,
#     'unconfirmedCount': 0},
#    'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#    'referralId': 'v-1574440731',
#    'venueChains': [],
#    'hasPerk': False},
#   {'id': '57195c6e498e3e95890ce3f3',
#    'name': "Phil's BBQ",
#    'contact': {},
#    'location': {'address': '17051 W Bernardo Dr',
#     'crossStreet': 'Rancho Bernardo Road',
#     'lat': 33.024106499033934,
#     'lng': -117.08094190959415,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 33.024106499033934,
#       'lng': -117.08094190959415}],
#     'postalCode': '92127',
#     'cc': 'US',
#     'neighborhood': 'Rancho Bernardo',
#     'city': 'San Diego',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['17051 W Bernardo Dr (Rancho Bernardo Road)',
#      'San Diego, CA 92127',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1df931735',
#      'name': 'BBQ Joint',
#      'pluralName': 'BBQ Joints',
#      'shortName': 'BBQ',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#       'suffix': '.png'},
#      'primary': True}],
#    'verified': False,
#    'stats': {'tipCount': 0,
#     'usersCount': 0,
#     'checkinsCount': 0,
#     'visitsCount': 0},
#    'beenHere': {'count': 0,
#     'lastCheckinExpiredAt': 0,
#     'marked': False,
#     'unconfirmedCount': 0},
#    'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#    'referralId': 'v-1574440731',
#    'venueChains': [],
#    'hasPerk': False},
#   {'id': '51412755e4b0096f798128b6',
#    'name': '9175 Judicial BBQ',
#    'contact': {},
#    'location': {'lat': 32.87367630004883,
#     'lng': -117.20423126220703,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 32.87367630004883,
#       'lng': -117.20423126220703}],
#     'cc': 'US',
#     'city': 'San Diego',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['San Diego, CA', 'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1df931735',
#      'name': 'BBQ Joint',
#      'pluralName': 'BBQ Joints',
#      'shortName': 'BBQ',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#       'suffix': '.png'},
#      'primary': True}],
#    'verified': False,
#    'stats': {'tipCount': 0,
#     'usersCount': 0,
#     'checkinsCount': 0,
#     'visitsCount': 0},
#    'beenHere': {'count': 0,
#     'lastCheckinExpiredAt': 0,
#     'marked': False,
#     'unconfirmedCount': 0},
#    'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#    'referralId': 'v-1574440731',
#    'venueChains': [],
#    'hasPerk': False},
#   {'id': '5ba707e03e6741002c41e911',
#    'name': 'Grand Ole BBQ Flinn Springs',
#    'contact': {},
#    'location': {'address': '15505 Olde Highway 80',
#     'lat': 32.855403383789856,
#     'lng': -116.83760974115364,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 32.855403383789856,
#       'lng': -116.83760974115364}],
#     'postalCode': '92021',
#     'cc': 'US',
#     'city': 'El Cajon',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['15505 Olde Highway 80',
#      'El Cajon, CA 92021',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1df931735',
#      'name': 'BBQ Joint',
#      'pluralName': 'BBQ Joints',
#      'shortName': 'BBQ',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#       'suffix': '.png'},
#      'primary': True}],
#    'verified': False,
#    'stats': {'tipCount': 0,
#     'usersCount': 0,
#     'checkinsCount': 0,
#     'visitsCount': 0},
#    'beenHere': {'count': 0,
#     'lastCheckinExpiredAt': 0,
#     'marked': False,
#     'unconfirmedCount': 0},
#    'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#    'referralId': 'v-1574440731',
#    'venueChains': [],
#    'hasPerk': False},
#   {'id': '5ca29c525a2c910039f05ac7',
#    'name': "Del's Hideout",
#    'contact': {},
#    'location': {'address': '5351 Adobe Falls Rd',
#     'crossStreet': 'Alvarado Canyon Road',
#     'lat': 32.781357477885614,
#     'lng': -117.08346605300905,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 32.781357477885614,
#       'lng': -117.08346605300905}],
#     'postalCode': '92120',
#     'cc': 'US',
#     'city': 'San Diego',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['5351 Adobe Falls Rd (Alvarado Canyon Road)',
#      'San Diego, CA 92120',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1df931735',
#      'name': 'BBQ Joint',
#      'pluralName': 'BBQ Joints',
#      'shortName': 'BBQ',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#       'suffix': '.png'},
#      'primary': True}],
#    'verified': True,
#    'stats': {'tipCount': 0,
#     'usersCount': 0,
#     'checkinsCount': 0,
#     'visitsCount': 0},
#    'beenHere': {'count': 0,
#     'lastCheckinExpiredAt': 0,
#     'marked': False,
#     'unconfirmedCount': 0},
#    'venuePage': {'id': '535063517'},
#    'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#    'referralId': 'v-1574440731',
#    'venueChains': [],
#    'hasPerk': False},
#   {'id': '5b305ff1efa82a002cc219af',
#    'name': 'The Pioneer',
#    'contact': {},
#    'location': {'address': '8622 Lake Murray Blvd',
#     'crossStreet': 'San Carlos Dr',
#     'lat': 32.8004995349775,
#     'lng': -117.01287964843145,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 32.8004995349775,
#       'lng': -117.01287964843145}],
#     'postalCode': '92119',
#     'cc': 'US',
#     'neighborhood': 'Lake Murray',
#     'city': 'San Diego',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['8622 Lake Murray Blvd (San Carlos Dr)',
#      'San Diego, CA 92119',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1df931735',
#      'name': 'BBQ Joint',
#      'pluralName': 'BBQ Joints',
#      'shortName': 'BBQ',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#       'suffix': '.png'},
#      'primary': True}],
#    'verified': False,
#    'stats': {'tipCount': 0,
#     'usersCount': 0,
#     'checkinsCount': 0,
#     'visitsCount': 0},
#    'beenHere': {'count': 0,
#     'lastCheckinExpiredAt': 0,
#     'marked': False,
#     'unconfirmedCount': 0},
#    'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#    'referralId': 'v-1574440731',
#    'venueChains': [],
#    'hasPerk': False},
#   {'id': '554ac835498efb9e60cfa4c9',
#    'name': 'Wood Ranch BBQ & Grill',
#    'contact': {},
#    'location': {'address': '7510 Hazard Center Dr. Unit 215',
#     'lat': 32.77007166525961,
#     'lng': -117.15960928364782,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 32.77007166525961,
#       'lng': -117.15960928364782}],
#     'postalCode': '92108',
#     'cc': 'US',
#     'city': 'San Diego',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['7510 Hazard Center Dr. Unit 215',
#      'San Diego, CA 92108',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1df931735',
#      'name': 'BBQ Joint',
#      'pluralName': 'BBQ Joints',
#      'shortName': 'BBQ',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#       'suffix': '.png'},
#      'primary': True}],
#    'verified': True,
#    'stats': {'tipCount': 0,
#     'usersCount': 0,
#     'checkinsCount': 0,
#     'visitsCount': 0},
#    'beenHere': {'count': 0,
#     'lastCheckinExpiredAt': 0,
#     'marked': False,
#     'unconfirmedCount': 0},
#    'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#    'referralId': 'v-1574440731',
#    'venueChains': [],
#    'hasPerk': False},
#   {'id': '4c6d440565eda093b30c4ed0',
#    'name': "Phil's BBQ",
#    'contact': {},
#    'location': {'address': '579 Grand Ave',
#     'crossStreet': 'at San Marcos Blvd.',
#     'lat': 33.13706323601799,
#     'lng': -117.17674899305733,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 33.13706323601799,
#       'lng': -117.17674899305733}],
#     'postalCode': '92078',
#     'cc': 'US',
#     'city': 'San Marcos',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['579 Grand Ave (at San Marcos Blvd.)',
#      'San Marcos, CA 92078',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1df931735',
#      'name': 'BBQ Joint',
#      'pluralName': 'BBQ Joints',
#      'shortName': 'BBQ',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#       'suffix': '.png'},
#      'primary': True}],
#    'verified': False,
#    'stats': {'tipCount': 0,
#     'usersCount': 0,
#     'checkinsCount': 0,
#     'visitsCount': 0},
#    'beenHere': {'count': 0,
#     'lastCheckinExpiredAt': 0,
#     'marked': False,
#     'unconfirmedCount': 0},
#    'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#    'referralId': 'v-1574440731',
#    'venueChains': [],
#    'hasPerk': False},
#   {'id': '5452dc71498ea5abf9a31300',
#    'name': 'Iron Pig Alehouse',
#    'contact': {},
#    'location': {'address': '1520 Garnet Ave',
#     'lat': 32.7996611083609,
#     'lng': -117.24225959446862,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 32.7996611083609,
#       'lng': -117.24225959446862}],
#     'postalCode': '92109',
#     'cc': 'US',
#     'city': 'San Diego',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['1520 Garnet Ave',
#      'San Diego, CA 92109',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1df931735',
#      'name': 'BBQ Joint',
#      'pluralName': 'BBQ Joints',
#      'shortName': 'BBQ',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#       'suffix': '.png'},
#      'primary': True}],
#    'verified': True,
#    'stats': {'tipCount': 0,
#     'usersCount': 0,
#     'checkinsCount': 0,
#     'visitsCount': 0},
#    'delivery': {'id': '319163',
#     'url': 'https://www.grubhub.com/restaurant/iron-pig-alehouse-1520-garnet-ave-san-diego/319163?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=319163',
#     'provider': {'name': 'grubhub',
#      'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#       'sizes': [40, 50],
#       'name': '/delivery_provider_grubhub_20180129.png'}}},
#    'beenHere': {'count': 0,
#     'lastCheckinExpiredAt': 0,
#     'marked': False,
#     'unconfirmedCount': 0},
#    'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#    'referralId': 'v-1574440731',
#    'venueChains': [],
#    'hasPerk': False},
#   {'id': '4ab5a433f964a520ba7520e3',
#    'name': 'Sam Woo BBQ',
#    'contact': {},
#    'location': {'address': '7330 Clairemont Mesa Blvd',
#     'crossStreet': 'In 99 Ranch Market',
#     'lat': 32.833717,
#     'lng': -117.16065,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 32.833717,
#       'lng': -117.16065}],
#     'postalCode': '92111',
#     'cc': 'US',
#     'neighborhood': 'Kearny Mesa',
#     'city': 'San Diego',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['7330 Clairemont Mesa Blvd (In 99 Ranch Market)',
#      'San Diego, CA 92111',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d145941735',
#      'name': 'Chinese Restaurant',
#      'pluralName': 'Chinese Restaurants',
#      'shortName': 'Chinese',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#       'suffix': '.png'},
#      'primary': True}],
#    'verified': False,
#    'stats': {'tipCount': 0,
#     'usersCount': 0,
#     'checkinsCount': 0,
#     'visitsCount': 0},
#    'beenHere': {'count': 0,
#     'lastCheckinExpiredAt': 0,
#     'marked': False,
#     'unconfirmedCount': 0},
#    'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#    'referralId': 'v-1574440731',
#    'venueChains': [],
#    'hasPerk': False},
#   {'id': '5074a839e4b07ac4790dadff',
#    'name': "Phil's BBQ",
#    'contact': {},
#    'location': {'address': '9816 Mission Gorge Rd',
#     'lat': 32.840576575013955,
#     'lng': -116.9833485278995,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 32.840576575013955,
#       'lng': -116.9833485278995}],
#     'postalCode': '92071',
#     'cc': 'US',
#     'city': 'Santee',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['9816 Mission Gorge Rd',
#      'Santee, CA 92071',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1df931735',
#      'name': 'BBQ Joint',
#      'pluralName': 'BBQ Joints',
#      'shortName': 'BBQ',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#       'suffix': '.png'},
#      'primary': True}],
#    'verified': False,
#    'stats': {'tipCount': 0,
#     'usersCount': 0,
#     'checkinsCount': 0,
#     'visitsCount': 0},
#    'beenHere': {'count': 0,
#     'lastCheckinExpiredAt': 0,
#     'marked': False,
#     'unconfirmedCount': 0},
#    'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#    'referralId': 'v-1574440731',
#    'venueChains': [],
#    'hasPerk': False},
#   {'id': '4a836510f964a52004fb1fe3',
#    'name': 'The Spot',
#    'contact': {},
#    'location': {'address': '1005 Prospect St',
#     'crossStreet': 'at Girard Ave',
#     'lat': 32.84745492346954,
#     'lng': -117.27455687246737,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 32.84745492346954,
#       'lng': -117.27455687246737}],
#     'postalCode': '92037',
#     'cc': 'US',
#     'city': 'La Jolla',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['1005 Prospect St (at Girard Ave)',
#      'La Jolla, CA 92037',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d116941735',
#      'name': 'Bar',
#      'pluralName': 'Bars',
#      'shortName': 'Bar',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#       'suffix': '.png'},
#      'primary': True}],
#    'verified': False,
#    'stats': {'tipCount': 0,
#     'usersCount': 0,
#     'checkinsCount': 0,
#     'visitsCount': 0},
#    'beenHere': {'count': 0,
#     'lastCheckinExpiredAt': 0,
#     'marked': False,
#     'unconfirmedCount': 0},
#    'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#    'referralId': 'v-1574440731',
#    'venueChains': [],
#    'hasPerk': False},
#   {'id': '4e078f4eb0fbba5eee1d0560',
#    'name': "Mike's BBQ",
#    'contact': {},
#    'location': {'address': '1356 W Valley Pkwy',
#     'lat': 33.11191590783339,
#     'lng': -117.10416144415515,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 33.11191590783339,
#       'lng': -117.10416144415515}],
#     'postalCode': '92029',
#     'cc': 'US',
#     'city': 'Escondido',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['1356 W Valley Pkwy',
#      'Escondido, CA 92029',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1df931735',
#      'name': 'BBQ Joint',
#      'pluralName': 'BBQ Joints',
#      'shortName': 'BBQ',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#       'suffix': '.png'},
#      'primary': True}],
#    'verified': True,
#    'stats': {'tipCount': 0,
#     'usersCount': 0,
#     'checkinsCount': 0,
#     'visitsCount': 0},
#    'beenHere': {'count': 0,
#     'lastCheckinExpiredAt': 0,
#     'marked': False,
#     'unconfirmedCount': 0},
#    'venuePage': {'id': '43636000'},
#    'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#    'referralId': 'v-1574440731',
#    'venueChains': [],
#    'hasPerk': False},
#   {'id': '4c0c4805a1b32d7f3e659cf0',
#    'name': 'West Coast BBQ and Brew',
#    'contact': {},
#    'location': {'address': '6126 Lake Murray Blvd',
#     'lat': 32.790949030093515,
#     'lng': -117.02143280185798,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 32.790949030093515,
#       'lng': -117.02143280185798}],
#     'postalCode': '91942',
#     'cc': 'US',
#     'city': 'La Mesa',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['6126 Lake Murray Blvd',
#      'La Mesa, CA 91942',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1df931735',
#      'name': 'BBQ Joint',
#      'pluralName': 'BBQ Joints',
#      'shortName': 'BBQ',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#       'suffix': '.png'},
#      'primary': True}],
#    'verified': True,
#    'stats': {'tipCount': 0,
#     'usersCount': 0,
#     'checkinsCount': 0,
#     'visitsCount': 0},
#    'beenHere': {'count': 0,
#     'lastCheckinExpiredAt': 0,
#     'marked': False,
#     'unconfirmedCount': 0},
#    'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#    'referralId': 'v-1574440731',
#    'venueChains': [],
#    'hasPerk': False},
#   {'id': '4fdc1081e4b0b4dd28be2c98',
#    'name': 'Kogi BBQ',
#    'contact': {},
#    'location': {'address': '5447 Kearny Villa Rd',
#     'lat': 32.832826846316415,
#     'lng': -117.13835186622883,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 32.832826846316415,
#       'lng': -117.13835186622883}],
#     'postalCode': '92123',
#     'cc': 'US',
#     'city': 'San Diego',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['5447 Kearny Villa Rd',
#      'San Diego, CA 92123',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d113941735',
#      'name': 'Korean Restaurant',
#      'pluralName': 'Korean Restaurants',
#      'shortName': 'Korean',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/korean_',
#       'suffix': '.png'},
#      'primary': True}],
#    'verified': False,
#    'stats': {'tipCount': 0,
#     'usersCount': 0,
#     'checkinsCount': 0,
#     'visitsCount': 0},
#    'beenHere': {'count': 0,
#     'lastCheckinExpiredAt': 0,
#     'marked': False,
#     'unconfirmedCount': 0},
#    'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#    'referralId': 'v-1574440731',
#    'venueChains': [],
#    'hasPerk': False},
#   {'id': '5474e871498efe80cf40b0b6',
#    'name': 'Manna BBQ',
#    'contact': {},
#    'location': {'address': '8188 Mira Mesa Blvd',
#     'lat': 32.913087651676605,
#     'lng': -117.14773611937966,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 32.913087651676605,
#       'lng': -117.14773611937966}],
#     'postalCode': '92126',
#     'cc': 'US',
#     'neighborhood': 'Mira Mesa',
#     'city': 'San Diego',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['8188 Mira Mesa Blvd',
#      'San Diego, CA 92126',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d113941735',
#      'name': 'Korean Restaurant',
#      'pluralName': 'Korean Restaurants',
#      'shortName': 'Korean',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/korean_',
#       'suffix': '.png'},
#      'primary': True}],
#    'verified': False,
#    'stats': {'tipCount': 0,
#     'usersCount': 0,
#     'checkinsCount': 0,
#     'visitsCount': 0},
#    'beenHere': {'count': 0,
#     'lastCheckinExpiredAt': 0,
#     'marked': False,
#     'unconfirmedCount': 0},
#    'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#    'referralId': 'v-1574440731',
#    'venueChains': [],
#    'hasPerk': False},
#   {'id': '52b17b66498eeab2c01f23f1',
#    'name': 'Gyu-Kaku Japanese BBQ',
#    'contact': {},
#    'location': {'address': '9844 Hibert St Ste G-1',
#     'lat': 32.91489994841389,
#     'lng': -117.11408912565088,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 32.91489994841389,
#       'lng': -117.11408912565088}],
#     'postalCode': '92131',
#     'cc': 'US',
#     'city': 'San Diego',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['9844 Hibert St Ste G-1',
#      'San Diego, CA 92131',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1df931735',
#      'name': 'BBQ Joint',
#      'pluralName': 'BBQ Joints',
#      'shortName': 'BBQ',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#       'suffix': '.png'},
#      'primary': True}],
#    'verified': True,
#    'stats': {'tipCount': 0,
#     'usersCount': 0,
#     'checkinsCount': 0,
#     'visitsCount': 0},
#    'beenHere': {'count': 0,
#     'lastCheckinExpiredAt': 0,
#     'marked': False,
#     'unconfirmedCount': 0},
#    'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#    'referralId': 'v-1574440731',
#    'venueChains': [],
#    'hasPerk': False},
#   {'id': '572a5d9ecd105e31e87c7034',
#    'name': "Carnitas' Snack Shack - Embarcadero",
#    'contact': {},
#    'location': {'address': '1004 N Harbor Dr',
#     'lat': 32.716212492353684,
#     'lng': -117.17325853410645,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 32.716212492353684,
#       'lng': -117.17325853410645}],
#     'postalCode': '92101',
#     'cc': 'US',
#     'neighborhood': 'Marina',
#     'city': 'San Diego',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['1004 N Harbor Dr',
#      'San Diego, CA 92101',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1df931735',
#      'name': 'BBQ Joint',
#      'pluralName': 'BBQ Joints',
#      'shortName': 'BBQ',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#       'suffix': '.png'},
#      'primary': True}],
#    'verified': False,
#    'stats': {'tipCount': 0,
#     'usersCount': 0,
#     'checkinsCount': 0,
#     'visitsCount': 0},
#    'delivery': {'id': '1431599',
#     'url': 'https://www.grubhub.com/restaurant/carnitas-snack-shack-1004-n-harbor-dr-san-diego/1431599?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1431599',
#     'provider': {'name': 'grubhub',
#      'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#       'sizes': [40, 50],
#       'name': '/delivery_provider_grubhub_20180129.png'}}},
#    'beenHere': {'count': 0,
#     'lastCheckinExpiredAt': 0,
#     'marked': False,
#     'unconfirmedCount': 0},
#    'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#    'referralId': 'v-1574440731',
#    'venueChains': [],
#    'hasPerk': False},
#   {'id': '566b3764498e25d72e3a6bb3',
#    'name': "BT's Southern BBQ",
#    'contact': {},
#    'location': {'address': '7845 Highland Village Pl # C101',
#     'crossStreet': 'Via Francesco',
#     'lat': 32.96200817645033,
#     'lng': -117.1542094760459,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 32.96200817645033,
#       'lng': -117.1542094760459}],
#     'postalCode': '92129',
#     'cc': 'US',
#     'city': 'San Diego',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['7845 Highland Village Pl # C101 (Via Francesco)',
#      'San Diego, CA 92129',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1df931735',
#      'name': 'BBQ Joint',
#      'pluralName': 'BBQ Joints',
#      'shortName': 'BBQ',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#       'suffix': '.png'},
#      'primary': True}],
#    'verified': False,
#    'stats': {'tipCount': 0,
#     'usersCount': 0,
#     'checkinsCount': 0,
#     'visitsCount': 0},
#    'delivery': {'id': '345737',
#     'url': 'https://www.grubhub.com/restaurant/bts-southern-bbq-7845-highlands-village-pl-ste-c-101-san-diego/345737?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=345737',
#     'provider': {'name': 'grubhub',
#      'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#       'sizes': [40, 50],
#       'name': '/delivery_provider_grubhub_20180129.png'}}},
#    'beenHere': {'count': 0,
#     'lastCheckinExpiredAt': 0,
#     'marked': False,
#     'unconfirmedCount': 0},
#    'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#    'referralId': 'v-1574440731',
#    'venueChains': [],
#    'hasPerk': False},
#   {'id': '40e0b100f964a52051021fe3',
#    'name': 'Kansas City Barbeque',
#    'contact': {},
#    'location': {'address': '600 W Harbor Dr',
#     'lat': 32.71155894618459,
#     'lng': -117.16864228248596,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 32.71155894618459,
#       'lng': -117.16864228248596}],
#     'postalCode': '92101',
#     'cc': 'US',
#     'city': 'San Diego',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['600 W Harbor Dr',
#      'San Diego, CA 92101',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1df931735',
#      'name': 'BBQ Joint',
#      'pluralName': 'BBQ Joints',
#      'shortName': 'BBQ',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#       'suffix': '.png'},
#      'primary': True}],
#    'verified': True,
#    'stats': {'tipCount': 0,
#     'usersCount': 0,
#     'checkinsCount': 0,
#     'visitsCount': 0},
#    'beenHere': {'count': 0,
#     'lastCheckinExpiredAt': 0,
#     'marked': False,
#     'unconfirmedCount': 0},
#    'venuePage': {'id': '187730990'},
#    'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#    'referralId': 'v-1574440731',
#    'venueChains': [],
#    'hasPerk': False},
#   {'id': '52071b7b11d2dfe8a4be8a1b',
#    'name': 'Cheers Bar & Grill',
#    'contact': {},
#    'location': {'address': '9995 Carmel Mountain Rd Ste B1',
#     'crossStreet': 'Rancho Penasquitos Blvd',
#     'lat': 32.95989377534602,
#     'lng': -117.11221859951345,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 32.95989377534602,
#       'lng': -117.11221859951345}],
#     'postalCode': '92129',
#     'cc': 'US',
#     'city': 'San Diego',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['9995 Carmel Mountain Rd Ste B1 (Rancho Penasquitos Blvd)',
#      'San Diego, CA 92129',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d116941735',
#      'name': 'Bar',
#      'pluralName': 'Bars',
#      'shortName': 'Bar',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#       'suffix': '.png'},
#      'primary': True}],
#    'verified': False,
#    'stats': {'tipCount': 0,
#     'usersCount': 0,
#     'checkinsCount': 0,
#     'visitsCount': 0},
#    'beenHere': {'count': 0,
#     'lastCheckinExpiredAt': 0,
#     'marked': False,
#     'unconfirmedCount': 0},
#    'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#    'referralId': 'v-1574440731',
#    'venueChains': [],
#    'hasPerk': False},
#   {'id': '5cf96e7d1acf11002c15294f',
#    'name': 'Ranchwood BBQ',
#    'contact': {},
#    'location': {'address': '2533 Folex Way',
#     'lat': 32.72718,
#     'lng': -116.965694,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 32.72718,
#       'lng': -116.965694}],
#     'postalCode': '91978',
#     'cc': 'US',
#     'city': 'Spring Valley',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['2533 Folex Way',
#      'Spring Valley, CA 91978',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1df931735',
#      'name': 'BBQ Joint',
#      'pluralName': 'BBQ Joints',
#      'shortName': 'BBQ',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#       'suffix': '.png'},
#      'primary': True}],
#    'verified': False,
#    'stats': {'tipCount': 0,
#     'usersCount': 0,
#     'checkinsCount': 0,
#     'visitsCount': 0},
#    'delivery': {'id': '789173',
#     'url': 'https://www.grubhub.com/restaurant/ranchwood-bbq--catering-2533-folex-way-spring-valley/789173?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=789173',
#     'provider': {'name': 'grubhub',
#      'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#       'sizes': [40, 50],
#       'name': '/delivery_provider_grubhub_20180129.png'}}},
#    'beenHere': {'count': 0,
#     'lastCheckinExpiredAt': 0,
#     'marked': False,
#     'unconfirmedCount': 0},
#    'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#    'referralId': 'v-1574440731',
#    'venueChains': [],
#    'hasPerk': False},
#   {'id': '56ef801d498e353289c0b8a7',
#    'name': 'Tacos Kike',
#    'contact': {},
#    'location': {'address': 'Panamericano',
#     'lat': 32.467143197050405,
#     'lng': -117.01236006774145,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 32.467143197050405,
#       'lng': -117.01236006774145}],
#     'cc': 'MX',
#     'city': 'Tijuana',
#     'state': 'Baja California',
#     'country': 'México',
#     'formattedAddress': ['Panamericano',
#      'Tijuana, Baja California',
#      'México']},
#    'categories': [{'id': '4bf58dd8d48988d1df931735',
#      'name': 'BBQ Joint',
#      'pluralName': 'BBQ Joints',
#      'shortName': 'BBQ',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#       'suffix': '.png'},
#      'primary': True}],
#    'verified': False,
#    'stats': {'tipCount': 0,
#     'usersCount': 0,
#     'checkinsCount': 0,
#     'visitsCount': 0},
#    'beenHere': {'count': 0,
#     'lastCheckinExpiredAt': 0,
#     'marked': False,
#     'unconfirmedCount': 0},
#    'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#    'referralId': 'v-1574440731',
#    'venueChains': [],
#    'hasPerk': False},
#   {'id': '4abd4e23f964a520a08920e3',
#    'name': "Bubba's Smokehouse",
#    'contact': {},
#    'location': {'address': '888 Prospect St',
#     'crossStreet': 'at Fay Ave',
#     'lat': 32.846657,
#     'lng': -117.275795,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 32.846657,
#       'lng': -117.275795}],
#     'postalCode': '92037',
#     'cc': 'US',
#     'neighborhood': 'Village',
#     'city': 'La Jolla',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['888 Prospect St (at Fay Ave)',
#      'La Jolla, CA 92037',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1df931735',
#      'name': 'BBQ Joint',
#      'pluralName': 'BBQ Joints',
#      'shortName': 'BBQ',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#       'suffix': '.png'},
#      'primary': True}],
#    'verified': False,
#    'stats': {'tipCount': 0,
#     'usersCount': 0,
#     'checkinsCount': 0,
#     'visitsCount': 0},
#    'beenHere': {'count': 0,
#     'lastCheckinExpiredAt': 0,
#     'marked': False,
#     'unconfirmedCount': 0},
#    'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#    'referralId': 'v-1574440731',
#    'venueChains': [],
#    'hasPerk': False},
#   {'id': '40e0b100f964a520f3011fe3',
#    'name': 'Coaster Saloon',
#    'contact': {},
#    'location': {'address': '744 Ventura Pl',
#     'crossStreet': 'btwn Ocean Front Walk & Mission Blvd.',
#     'lat': 32.77211402646753,
#     'lng': -117.25180574511823,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 32.77211402646753,
#       'lng': -117.25180574511823}],
#     'postalCode': '92109',
#     'cc': 'US',
#     'city': 'San Diego',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['744 Ventura Pl (btwn Ocean Front Walk & Mission Blvd.)',
#      'San Diego, CA 92109',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d16c941735',
#      'name': 'Burger Joint',
#      'pluralName': 'Burger Joints',
#      'shortName': 'Burgers',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burger_',
#       'suffix': '.png'},
#      'primary': True}],
#    'verified': True,
#    'stats': {'tipCount': 0,
#     'usersCount': 0,
#     'checkinsCount': 0,
#     'visitsCount': 0},
#    'beenHere': {'count': 0,
#     'lastCheckinExpiredAt': 0,
#     'marked': False,
#     'unconfirmedCount': 0},
#    'venuePage': {'id': '461296831'},
#    'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#    'referralId': 'v-1574440731',
#    'venueChains': [],
#    'hasPerk': False},
#   {'id': '4bfc2322e05e0f470c40cfa8',
#    'name': 'Calypso Bay Smokehouse',
#    'contact': {},
#    'location': {'address': '500 Sea World Dr',
#     'crossStreet': 'SeaWorld San Diego',
#     'lat': 32.76585048561616,
#     'lng': -117.22465606980798,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 32.76585048561616,
#       'lng': -117.22465606980798}],
#     'postalCode': '92109',
#     'cc': 'US',
#     'city': 'San Diego',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['500 Sea World Dr (SeaWorld San Diego)',
#      'San Diego, CA 92109',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1df931735',
#      'name': 'BBQ Joint',
#      'pluralName': 'BBQ Joints',
#      'shortName': 'BBQ',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#       'suffix': '.png'},
#      'primary': True}],
#    'verified': False,
#    'stats': {'tipCount': 0,
#     'usersCount': 0,
#     'checkinsCount': 0,
#     'visitsCount': 0},
#    'beenHere': {'count': 0,
#     'lastCheckinExpiredAt': 0,
#     'marked': False,
#     'unconfirmedCount': 0},
#    'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#    'referralId': 'v-1574440731',
#    'venueChains': [],
#    'hasPerk': False},
#   {'id': '4b4d21e4f964a5201ccc26e3',
#    'name': "Bull's Smokin BBQ",
#    'contact': {},
#    'location': {'address': '1127 W Morena Blvd',
#     'lat': 32.76853788117238,
#     'lng': -117.20100254785041,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 32.76853788117238,
#       'lng': -117.20100254785041}],
#     'postalCode': '92110',
#     'cc': 'US',
#     'city': 'San Diego',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['1127 W Morena Blvd',
#      'San Diego, CA 92110',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1df931735',
#      'name': 'BBQ Joint',
#      'pluralName': 'BBQ Joints',
#      'shortName': 'BBQ',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#       'suffix': '.png'},
#      'primary': True}],
#    'verified': False,
#    'stats': {'tipCount': 0,
#     'usersCount': 0,
#     'checkinsCount': 0,
#     'visitsCount': 0},
#    'beenHere': {'count': 0,
#     'lastCheckinExpiredAt': 0,
#     'marked': False,
#     'unconfirmedCount': 0},
#    'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#    'referralId': 'v-1574440731',
#    'venueChains': [],
#    'hasPerk': False},
#   {'id': '4a9054fcf964a520551720e3',
#    'name': "Lil' Piggy's Bar-B-Q",
#    'contact': {},
#    'location': {'address': '1201 1st St',
#     'lat': 32.69882014707074,
#     'lng': -117.16983393235117,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 32.69882014707074,
#       'lng': -117.16983393235117}],
#     'postalCode': '92118',
#     'cc': 'US',
#     'city': 'Coronado',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['1201 1st St',
#      'Coronado, CA 92118',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1df931735',
#      'name': 'BBQ Joint',
#      'pluralName': 'BBQ Joints',
#      'shortName': 'BBQ',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#       'suffix': '.png'},
#      'primary': True}],
#    'verified': False,
#    'stats': {'tipCount': 0,
#     'usersCount': 0,
#     'checkinsCount': 0,
#     'visitsCount': 0},
#    'delivery': {'id': '985668',
#     'url': 'https://www.grubhub.com/restaurant/lil-piggys-barbq-1201-1st-st-coronado/985668?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=985668',
#     'provider': {'name': 'grubhub',
#      'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#       'sizes': [40, 50],
#       'name': '/delivery_provider_grubhub_20180129.png'}}},
#    'beenHere': {'count': 0,
#     'lastCheckinExpiredAt': 0,
#     'marked': False,
#     'unconfirmedCount': 0},
#    'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#    'referralId': 'v-1574440731',
#    'venueChains': [],
#    'hasPerk': False}],
#  'confident': False,
#  'geocode': {'what': '',
#   'where': 'san diego',
#   'feature': {'cc': 'US',
#    'name': 'San Diego',
#    'displayName': 'San Diego, CA, United States',
#    'matchedName': 'San Diego, CA, United States',
#    'highlightedName': '<b>San Diego</b>, CA, United States',
#    'woeType': 7,
#    'slug': 'san-diego-california',
#    'id': 'geonameid:5391811',
#    'longId': '72057594043319747',
#    'geometry': {'center': {'lat': 32.71533, 'lng': -117.15726},
#     'bounds': {'ne': {'lat': 33.114185, 'lng': -116.905723},
#      'sw': {'lat': 32.534870999999995, 'lng': -117.309797}}}},
#   'parents': []}}

# %% [markdown]
# #### File Structure of *this* JSON response
#
# Venues \
# ├── ID \
# ├── Name \
# ├── Contact \
# └── Location \
# . . . . .├── Latitude \
# . . . . .├── Longitude \
# . . . . .├── Postal Code \
# . . . . .├── City \
# . . . . .└── State
#
# #### Cool. So how do we access this data?
# All you have to do is treat it like a panda dataframe! \
# `data['venues']` gives you a list of all the Restaurants that it returned \
# Lets use that to make a `for` loop to iterate through all the restaurants and use 'name' value to get the name!

# %%
for restaurant in data['venues']:
    print(restaurant['name'])
# Out:
# Gaslamp BBQ
# Phil's BBQ
# Phil's BBQ
# Phil's BBQ
# 9175 Judicial BBQ
# Grand Ole BBQ Flinn Springs
# Del's Hideout
# The Pioneer
# Wood Ranch BBQ & Grill
# Phil's BBQ
# Iron Pig Alehouse
# Sam Woo BBQ
# Phil's BBQ
# The Spot
# Mike's BBQ
# West Coast BBQ and Brew
# Kogi BBQ
# Manna BBQ
# Gyu-Kaku Japanese BBQ
# Carnitas' Snack Shack - Embarcadero
# BT's Southern BBQ
# Kansas City Barbeque
# Cheers Bar & Grill
# Ranchwood BBQ
# Tacos Kike
# Bubba's Smokehouse
# Coaster Saloon
# Calypso Bay Smokehouse
# Bull's Smokin BBQ
# Lil' Piggy's Bar-B-Q

# %% [markdown]
# ### Let's put it into a Pandas dataframe

# %%
## Create a dictionary with the a list as the value
restaurant_dict = {'id':[],'name':[],'category':[],'category_id':[]}

## Loop through each retaurant and append the respective fields
for restaurant in data['venues']:
    restaurant_dict['id'].append(restaurant['id'])
    restaurant_dict['name'].append(restaurant['name'])
    restaurant_dict['category'].append(restaurant['categories'][0]['name'])
    restaurant_dict['category_id'].append(restaurant['categories'][0]['id'])
    
## Make a pandas dataframe with the dictionary    
df = pd.DataFrame.from_dict(restaurant_dict)

restaurant_dict
# Out:
# {'id': ['51bd1640498e9a4f3c67a5c8',
#   '5203ccf0498e4458881c39d3',
#   '460d2cfcf964a52002451fe3',
#   '57195c6e498e3e95890ce3f3',
#   '51412755e4b0096f798128b6',
#   '5ba707e03e6741002c41e911',
#   '5ca29c525a2c910039f05ac7',
#   '5b305ff1efa82a002cc219af',
#   '554ac835498efb9e60cfa4c9',
#   '4c6d440565eda093b30c4ed0',
#   '5452dc71498ea5abf9a31300',
#   '4ab5a433f964a520ba7520e3',
#   '5074a839e4b07ac4790dadff',
#   '4a836510f964a52004fb1fe3',
#   '4e078f4eb0fbba5eee1d0560',
#   '4c0c4805a1b32d7f3e659cf0',
#   '4fdc1081e4b0b4dd28be2c98',
#   '5474e871498efe80cf40b0b6',
#   '52b17b66498eeab2c01f23f1',
#   '572a5d9ecd105e31e87c7034',
#   '566b3764498e25d72e3a6bb3',
#   '40e0b100f964a52051021fe3',
#   '52071b7b11d2dfe8a4be8a1b',
#   '5cf96e7d1acf11002c15294f',
#   '56ef801d498e353289c0b8a7',
#   '4abd4e23f964a520a08920e3',
#   '40e0b100f964a520f3011fe3',
#   '4bfc2322e05e0f470c40cfa8',
#   '4b4d21e4f964a5201ccc26e3',
#   '4a9054fcf964a520551720e3'],
#  'name': ['Gaslamp BBQ',
#   "Phil's BBQ",
#   "Phil's BBQ",
#   "Phil's BBQ",
#   '9175 Judicial BBQ',
#   'Grand Ole BBQ Flinn Springs',
#   "Del's Hideout",
#   'The Pioneer',
#   'Wood Ranch BBQ & Grill',
#   "Phil's BBQ",
#   'Iron Pig Alehouse',
#   'Sam Woo BBQ',
#   "Phil's BBQ",
#   'The Spot',
#   "Mike's BBQ",
#   'West Coast BBQ and Brew',
#   'Kogi BBQ',
#   'Manna BBQ',
#   'Gyu-Kaku Japanese BBQ',
#   "Carnitas' Snack Shack - Embarcadero",
#   "BT's Southern BBQ",
#   'Kansas City Barbeque',
#   'Cheers Bar & Grill',
#   'Ranchwood BBQ',
#   'Tacos Kike',
#   "Bubba's Smokehouse",
#   'Coaster Saloon',
#   'Calypso Bay Smokehouse',
#   "Bull's Smokin BBQ",
#   "Lil' Piggy's Bar-B-Q"],
#  'category': ['Bar',
#   'BBQ Joint',
#   'BBQ Joint',
#   'BBQ Joint',
#   'BBQ Joint',
#   'BBQ Joint',
#   'BBQ Joint',
#   'BBQ Joint',
#   'BBQ Joint',
#   'BBQ Joint',
#   'BBQ Joint',
#   'Chinese Restaurant',
#   'BBQ Joint',
#   'Bar',
#   'BBQ Joint',
#   'BBQ Joint',
#   'Korean Restaurant',
#   'Korean Restaurant',
#   'BBQ Joint',
#   'BBQ Joint',
#   'BBQ Joint',
#   'BBQ Joint',
#   'Bar',
#   'BBQ Joint',
#   'BBQ Joint',
#   'BBQ Joint',
#   'Burger Joint',
#   'BBQ Joint',
#   'BBQ Joint',
#   'BBQ Joint'],
#  'category_id': ['4bf58dd8d48988d116941735',
#   '4bf58dd8d48988d1df931735',
#   '4bf58dd8d48988d1df931735',
#   '4bf58dd8d48988d1df931735',
#   '4bf58dd8d48988d1df931735',
#   '4bf58dd8d48988d1df931735',
#   '4bf58dd8d48988d1df931735',
#   '4bf58dd8d48988d1df931735',
#   '4bf58dd8d48988d1df931735',
#   '4bf58dd8d48988d1df931735',
#   '4bf58dd8d48988d1df931735',
#   '4bf58dd8d48988d145941735',
#   '4bf58dd8d48988d1df931735',
#   '4bf58dd8d48988d116941735',
#   '4bf58dd8d48988d1df931735',
#   '4bf58dd8d48988d1df931735',
#   '4bf58dd8d48988d113941735',
#   '4bf58dd8d48988d113941735',
#   '4bf58dd8d48988d1df931735',
#   '4bf58dd8d48988d1df931735',
#   '4bf58dd8d48988d1df931735',
#   '4bf58dd8d48988d1df931735',
#   '4bf58dd8d48988d116941735',
#   '4bf58dd8d48988d1df931735',
#   '4bf58dd8d48988d1df931735',
#   '4bf58dd8d48988d1df931735',
#   '4bf58dd8d48988d16c941735',
#   '4bf58dd8d48988d1df931735',
#   '4bf58dd8d48988d1df931735',
#   '4bf58dd8d48988d1df931735']}

# %%
df.head()
# Out:
#                          id               name   category  \
# 0  51bd1640498e9a4f3c67a5c8        Gaslamp BBQ        Bar
# 1  5203ccf0498e4458881c39d3         Phil's BBQ  BBQ Joint
# 2  460d2cfcf964a52002451fe3         Phil's BBQ  BBQ Joint
# 3  57195c6e498e3e95890ce3f3         Phil's BBQ  BBQ Joint
# 4  51412755e4b0096f798128b6  9175 Judicial BBQ  BBQ Joint
#
#                 category_id
# 0  4bf58dd8d48988d116941735
# 1  4bf58dd8d48988d1df931735
# 2  4bf58dd8d48988d1df931735
# 3  4bf58dd8d48988d1df931735
# 4  4bf58dd8d48988d1df931735

# %% [markdown]
# Awesome! Now let's try and add the address to the dataframe.
#
# We'll use the same way. Use the `for` loop to go through them all.

# %%
addresses = []

for restaurant in data['venues']:
    addresses.append(restaurant['location']['address'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-25-315b9cb3c29c> in <module>
#       2
#       3 for restaurant in data['venues']:
# ----> 4     addresses.append(restaurant['location']['address'])
#
# KeyError: 'address'

# %% [markdown]
# Why didn't this work? \
#
# Sometimes when a result doesn't have the value specified, like a food truck, *some* APIs will just not send you anything instead of sending you a blank key/value pair.\
# So what's the point, if you can't use a for loop? \
#
# Lucky for us, we can create something to give us a NaN value!

# %%
addresses = []

for restaurant in data['venues']:
    try:
        ## Set it to the address
        addresses.append(restaurant["location"]['address'])
    except KeyError:
        ## Set it to NaN
        addresses.append(np.NaN)
        
addresses
# Out:
# ['524 Island Ave',
#  'Terminal 2',
#  '3740 Sports Arena Blvd',
#  '17051 W Bernardo Dr',
#  nan,
#  '15505 Olde Highway 80',
#  '5351 Adobe Falls Rd',
#  '8622 Lake Murray Blvd',
#  '7510 Hazard Center Dr. Unit 215',
#  '579 Grand Ave',
#  '1520 Garnet Ave',
#  '7330 Clairemont Mesa Blvd',
#  '9816 Mission Gorge Rd',
#  '1005 Prospect St',
#  '1356 W Valley Pkwy',
#  '6126 Lake Murray Blvd',
#  '5447 Kearny Villa Rd',
#  '8188 Mira Mesa Blvd',
#  '9844 Hibert St Ste G-1',
#  '1004 N Harbor Dr',
#  '7845 Highland Village Pl # C101',
#  '600 W Harbor Dr',
#  '9995 Carmel Mountain Rd Ste B1',
#  '2533 Folex Way',
#  'Panamericano',
#  '888 Prospect St',
#  '744 Ventura Pl',
#  '500 Sea World Dr',
#  '1127 W Morena Blvd',
#  '1201 1st St']

# %% [markdown]
# Time to add to the dataframe!

# %%
df['address'] = addresses

print(df.isna().sum())
df.head()
# Out:
# id             0
# name           0
# category       0
# category_id    0
# address        1
# dtype: int64
#                          id               name   category  \
# 0  51bd1640498e9a4f3c67a5c8        Gaslamp BBQ        Bar
# 1  5203ccf0498e4458881c39d3         Phil's BBQ  BBQ Joint
# 2  460d2cfcf964a52002451fe3         Phil's BBQ  BBQ Joint
# 3  57195c6e498e3e95890ce3f3         Phil's BBQ  BBQ Joint
# 4  51412755e4b0096f798128b6  9175 Judicial BBQ  BBQ Joint
#
#                 category_id                 address
# 0  4bf58dd8d48988d116941735          524 Island Ave
# 1  4bf58dd8d48988d1df931735              Terminal 2
# 2  4bf58dd8d48988d1df931735  3740 Sports Arena Blvd
# 3  4bf58dd8d48988d1df931735     17051 W Bernardo Dr
# 4  4bf58dd8d48988d1df931735                     NaN

# %% [markdown]
# That's a lot of work, so let's make a function to handle the error stuff for us.

# %%
def check_errors(json_data, key_name):
    try:
        ## Set it to the the key value
        return json_data[key_name]
    except KeyError:
        ## Set it to NaN
        return np.NaN

# %% [markdown]
# Now to add the zip code, state, and city

# %%
cities = []
zips = []
states = []

for restaurant in data['venues']:
    cities.append(check_errors(restaurant['location'],'city'))
    zips.append(check_errors(restaurant['location'],'postalCode'))
    states.append(check_errors(restaurant['location'],'state'))

# %%
df['citiy'], df['state'], df['zip_code'] = [cities, states, zips]

df.head()
# Out:
#                          id               name   category  \
# 0  51bd1640498e9a4f3c67a5c8        Gaslamp BBQ        Bar
# 1  5203ccf0498e4458881c39d3         Phil's BBQ  BBQ Joint
# 2  460d2cfcf964a52002451fe3         Phil's BBQ  BBQ Joint
# 3  57195c6e498e3e95890ce3f3         Phil's BBQ  BBQ Joint
# 4  51412755e4b0096f798128b6  9175 Judicial BBQ  BBQ Joint
#
#                 category_id                 address      citiy state zip_code
# 0  4bf58dd8d48988d116941735          524 Island Ave  San Diego    CA    92101
# 1  4bf58dd8d48988d1df931735              Terminal 2  San Diego    CA    92110
# 2  4bf58dd8d48988d1df931735  3740 Sports Arena Blvd  San Diego    CA    92110
# 3  4bf58dd8d48988d1df931735     17051 W Bernardo Dr  San Diego    CA    92127
# 4  4bf58dd8d48988d1df931735                     NaN  San Diego    CA      NaN

# %% [markdown]
# ### Your turn!
#
# Add the column 'Verified' to dataframe using our function!

# %%
## Your code here
data
# Out:
# {'venues': [{'id': '51bd1640498e9a4f3c67a5c8',
#    'name': 'Gaslamp BBQ',
#    'contact': {},
#    'location': {'address': '524 Island Ave',
#     'lat': 32.710492957951836,
#     'lng': -117.15982530474932,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 32.710492957951836,
#       'lng': -117.15982530474932}],
#     'postalCode': '92101',
#     'cc': 'US',
#     'neighborhood': 'Gaslamp',
#     'city': 'San Diego',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['524 Island Ave',
#      'San Diego, CA 92101',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d116941735',
#      'name': 'Bar',
#      'pluralName': 'Bars',
#      'shortName': 'Bar',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#       'suffix': '.png'},
#      'primary': True}],
#    'verified': True,
#    'stats': {'tipCount': 0,
#     'usersCount': 0,
#     'checkinsCount': 0,
#     'visitsCount': 0},
#    'beenHere': {'count': 0,
#     'lastCheckinExpiredAt': 0,
#     'marked': False,
#     'unconfirmedCount': 0},
#    'venuePage': {'id': '83375008'},
#    'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#    'referralId': 'v-1574440731',
#    'venueChains': [],
#    'hasPerk': False},
#   {'id': '5203ccf0498e4458881c39d3',
#    'name': "Phil's BBQ",
#    'contact': {},
#    'location': {'address': 'Terminal 2',
#     'crossStreet': 'at SAN Airport',
#     'lat': 32.73398500762943,
#     'lng': -117.20422302549987,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 32.73398500762943,
#       'lng': -117.20422302549987}],
#     'postalCode': '92110',
#     'cc': 'US',
#     'city': 'San Diego',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['Terminal 2 (at SAN Airport)',
#      'San Diego, CA 92110',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1df931735',
#      'name': 'BBQ Joint',
#      'pluralName': 'BBQ Joints',
#      'shortName': 'BBQ',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#       'suffix': '.png'},
#      'primary': True}],
#    'verified': False,
#    'stats': {'tipCount': 0,
#     'usersCount': 0,
#     'checkinsCount': 0,
#     'visitsCount': 0},
#    'beenHere': {'count': 0,
#     'lastCheckinExpiredAt': 0,
#     'marked': False,
#     'unconfirmedCount': 0},
#    'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#    'referralId': 'v-1574440731',
#    'venueChains': [],
#    'hasPerk': False},
#   {'id': '460d2cfcf964a52002451fe3',
#    'name': "Phil's BBQ",
#    'contact': {},
#    'location': {'address': '3740 Sports Arena Blvd',
#     'crossStreet': 'at Hancock St.',
#     'lat': 32.75482013180317,
#     'lng': -117.21582764351203,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 32.75482013180317,
#       'lng': -117.21582764351203}],
#     'postalCode': '92110',
#     'cc': 'US',
#     'city': 'San Diego',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['3740 Sports Arena Blvd (at Hancock St.)',
#      'San Diego, CA 92110',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1df931735',
#      'name': 'BBQ Joint',
#      'pluralName': 'BBQ Joints',
#      'shortName': 'BBQ',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#       'suffix': '.png'},
#      'primary': True}],
#    'verified': False,
#    'stats': {'tipCount': 0,
#     'usersCount': 0,
#     'checkinsCount': 0,
#     'visitsCount': 0},
#    'beenHere': {'count': 0,
#     'lastCheckinExpiredAt': 0,
#     'marked': False,
#     'unconfirmedCount': 0},
#    'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#    'referralId': 'v-1574440731',
#    'venueChains': [],
#    'hasPerk': False},
#   {'id': '57195c6e498e3e95890ce3f3',
#    'name': "Phil's BBQ",
#    'contact': {},
#    'location': {'address': '17051 W Bernardo Dr',
#     'crossStreet': 'Rancho Bernardo Road',
#     'lat': 33.024106499033934,
#     'lng': -117.08094190959415,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 33.024106499033934,
#       'lng': -117.08094190959415}],
#     'postalCode': '92127',
#     'cc': 'US',
#     'neighborhood': 'Rancho Bernardo',
#     'city': 'San Diego',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['17051 W Bernardo Dr (Rancho Bernardo Road)',
#      'San Diego, CA 92127',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1df931735',
#      'name': 'BBQ Joint',
#      'pluralName': 'BBQ Joints',
#      'shortName': 'BBQ',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#       'suffix': '.png'},
#      'primary': True}],
#    'verified': False,
#    'stats': {'tipCount': 0,
#     'usersCount': 0,
#     'checkinsCount': 0,
#     'visitsCount': 0},
#    'beenHere': {'count': 0,
#     'lastCheckinExpiredAt': 0,
#     'marked': False,
#     'unconfirmedCount': 0},
#    'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#    'referralId': 'v-1574440731',
#    'venueChains': [],
#    'hasPerk': False},
#   {'id': '51412755e4b0096f798128b6',
#    'name': '9175 Judicial BBQ',
#    'contact': {},
#    'location': {'lat': 32.87367630004883,
#     'lng': -117.20423126220703,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 32.87367630004883,
#       'lng': -117.20423126220703}],
#     'cc': 'US',
#     'city': 'San Diego',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['San Diego, CA', 'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1df931735',
#      'name': 'BBQ Joint',
#      'pluralName': 'BBQ Joints',
#      'shortName': 'BBQ',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#       'suffix': '.png'},
#      'primary': True}],
#    'verified': False,
#    'stats': {'tipCount': 0,
#     'usersCount': 0,
#     'checkinsCount': 0,
#     'visitsCount': 0},
#    'beenHere': {'count': 0,
#     'lastCheckinExpiredAt': 0,
#     'marked': False,
#     'unconfirmedCount': 0},
#    'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#    'referralId': 'v-1574440731',
#    'venueChains': [],
#    'hasPerk': False},
#   {'id': '5ba707e03e6741002c41e911',
#    'name': 'Grand Ole BBQ Flinn Springs',
#    'contact': {},
#    'location': {'address': '15505 Olde Highway 80',
#     'lat': 32.855403383789856,
#     'lng': -116.83760974115364,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 32.855403383789856,
#       'lng': -116.83760974115364}],
#     'postalCode': '92021',
#     'cc': 'US',
#     'city': 'El Cajon',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['15505 Olde Highway 80',
#      'El Cajon, CA 92021',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1df931735',
#      'name': 'BBQ Joint',
#      'pluralName': 'BBQ Joints',
#      'shortName': 'BBQ',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#       'suffix': '.png'},
#      'primary': True}],
#    'verified': False,
#    'stats': {'tipCount': 0,
#     'usersCount': 0,
#     'checkinsCount': 0,
#     'visitsCount': 0},
#    'beenHere': {'count': 0,
#     'lastCheckinExpiredAt': 0,
#     'marked': False,
#     'unconfirmedCount': 0},
#    'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#    'referralId': 'v-1574440731',
#    'venueChains': [],
#    'hasPerk': False},
#   {'id': '5ca29c525a2c910039f05ac7',
#    'name': "Del's Hideout",
#    'contact': {},
#    'location': {'address': '5351 Adobe Falls Rd',
#     'crossStreet': 'Alvarado Canyon Road',
#     'lat': 32.781357477885614,
#     'lng': -117.08346605300905,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 32.781357477885614,
#       'lng': -117.08346605300905}],
#     'postalCode': '92120',
#     'cc': 'US',
#     'city': 'San Diego',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['5351 Adobe Falls Rd (Alvarado Canyon Road)',
#      'San Diego, CA 92120',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1df931735',
#      'name': 'BBQ Joint',
#      'pluralName': 'BBQ Joints',
#      'shortName': 'BBQ',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#       'suffix': '.png'},
#      'primary': True}],
#    'verified': True,
#    'stats': {'tipCount': 0,
#     'usersCount': 0,
#     'checkinsCount': 0,
#     'visitsCount': 0},
#    'beenHere': {'count': 0,
#     'lastCheckinExpiredAt': 0,
#     'marked': False,
#     'unconfirmedCount': 0},
#    'venuePage': {'id': '535063517'},
#    'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#    'referralId': 'v-1574440731',
#    'venueChains': [],
#    'hasPerk': False},
#   {'id': '5b305ff1efa82a002cc219af',
#    'name': 'The Pioneer',
#    'contact': {},
#    'location': {'address': '8622 Lake Murray Blvd',
#     'crossStreet': 'San Carlos Dr',
#     'lat': 32.8004995349775,
#     'lng': -117.01287964843145,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 32.8004995349775,
#       'lng': -117.01287964843145}],
#     'postalCode': '92119',
#     'cc': 'US',
#     'neighborhood': 'Lake Murray',
#     'city': 'San Diego',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['8622 Lake Murray Blvd (San Carlos Dr)',
#      'San Diego, CA 92119',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1df931735',
#      'name': 'BBQ Joint',
#      'pluralName': 'BBQ Joints',
#      'shortName': 'BBQ',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#       'suffix': '.png'},
#      'primary': True}],
#    'verified': False,
#    'stats': {'tipCount': 0,
#     'usersCount': 0,
#     'checkinsCount': 0,
#     'visitsCount': 0},
#    'beenHere': {'count': 0,
#     'lastCheckinExpiredAt': 0,
#     'marked': False,
#     'unconfirmedCount': 0},
#    'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#    'referralId': 'v-1574440731',
#    'venueChains': [],
#    'hasPerk': False},
#   {'id': '554ac835498efb9e60cfa4c9',
#    'name': 'Wood Ranch BBQ & Grill',
#    'contact': {},
#    'location': {'address': '7510 Hazard Center Dr. Unit 215',
#     'lat': 32.77007166525961,
#     'lng': -117.15960928364782,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 32.77007166525961,
#       'lng': -117.15960928364782}],
#     'postalCode': '92108',
#     'cc': 'US',
#     'city': 'San Diego',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['7510 Hazard Center Dr. Unit 215',
#      'San Diego, CA 92108',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1df931735',
#      'name': 'BBQ Joint',
#      'pluralName': 'BBQ Joints',
#      'shortName': 'BBQ',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#       'suffix': '.png'},
#      'primary': True}],
#    'verified': True,
#    'stats': {'tipCount': 0,
#     'usersCount': 0,
#     'checkinsCount': 0,
#     'visitsCount': 0},
#    'beenHere': {'count': 0,
#     'lastCheckinExpiredAt': 0,
#     'marked': False,
#     'unconfirmedCount': 0},
#    'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#    'referralId': 'v-1574440731',
#    'venueChains': [],
#    'hasPerk': False},
#   {'id': '4c6d440565eda093b30c4ed0',
#    'name': "Phil's BBQ",
#    'contact': {},
#    'location': {'address': '579 Grand Ave',
#     'crossStreet': 'at San Marcos Blvd.',
#     'lat': 33.13706323601799,
#     'lng': -117.17674899305733,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 33.13706323601799,
#       'lng': -117.17674899305733}],
#     'postalCode': '92078',
#     'cc': 'US',
#     'city': 'San Marcos',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['579 Grand Ave (at San Marcos Blvd.)',
#      'San Marcos, CA 92078',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1df931735',
#      'name': 'BBQ Joint',
#      'pluralName': 'BBQ Joints',
#      'shortName': 'BBQ',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#       'suffix': '.png'},
#      'primary': True}],
#    'verified': False,
#    'stats': {'tipCount': 0,
#     'usersCount': 0,
#     'checkinsCount': 0,
#     'visitsCount': 0},
#    'beenHere': {'count': 0,
#     'lastCheckinExpiredAt': 0,
#     'marked': False,
#     'unconfirmedCount': 0},
#    'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#    'referralId': 'v-1574440731',
#    'venueChains': [],
#    'hasPerk': False},
#   {'id': '5452dc71498ea5abf9a31300',
#    'name': 'Iron Pig Alehouse',
#    'contact': {},
#    'location': {'address': '1520 Garnet Ave',
#     'lat': 32.7996611083609,
#     'lng': -117.24225959446862,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 32.7996611083609,
#       'lng': -117.24225959446862}],
#     'postalCode': '92109',
#     'cc': 'US',
#     'city': 'San Diego',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['1520 Garnet Ave',
#      'San Diego, CA 92109',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1df931735',
#      'name': 'BBQ Joint',
#      'pluralName': 'BBQ Joints',
#      'shortName': 'BBQ',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#       'suffix': '.png'},
#      'primary': True}],
#    'verified': True,
#    'stats': {'tipCount': 0,
#     'usersCount': 0,
#     'checkinsCount': 0,
#     'visitsCount': 0},
#    'delivery': {'id': '319163',
#     'url': 'https://www.grubhub.com/restaurant/iron-pig-alehouse-1520-garnet-ave-san-diego/319163?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=319163',
#     'provider': {'name': 'grubhub',
#      'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#       'sizes': [40, 50],
#       'name': '/delivery_provider_grubhub_20180129.png'}}},
#    'beenHere': {'count': 0,
#     'lastCheckinExpiredAt': 0,
#     'marked': False,
#     'unconfirmedCount': 0},
#    'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#    'referralId': 'v-1574440731',
#    'venueChains': [],
#    'hasPerk': False},
#   {'id': '4ab5a433f964a520ba7520e3',
#    'name': 'Sam Woo BBQ',
#    'contact': {},
#    'location': {'address': '7330 Clairemont Mesa Blvd',
#     'crossStreet': 'In 99 Ranch Market',
#     'lat': 32.833717,
#     'lng': -117.16065,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 32.833717,
#       'lng': -117.16065}],
#     'postalCode': '92111',
#     'cc': 'US',
#     'neighborhood': 'Kearny Mesa',
#     'city': 'San Diego',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['7330 Clairemont Mesa Blvd (In 99 Ranch Market)',
#      'San Diego, CA 92111',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d145941735',
#      'name': 'Chinese Restaurant',
#      'pluralName': 'Chinese Restaurants',
#      'shortName': 'Chinese',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#       'suffix': '.png'},
#      'primary': True}],
#    'verified': False,
#    'stats': {'tipCount': 0,
#     'usersCount': 0,
#     'checkinsCount': 0,
#     'visitsCount': 0},
#    'beenHere': {'count': 0,
#     'lastCheckinExpiredAt': 0,
#     'marked': False,
#     'unconfirmedCount': 0},
#    'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#    'referralId': 'v-1574440731',
#    'venueChains': [],
#    'hasPerk': False},
#   {'id': '5074a839e4b07ac4790dadff',
#    'name': "Phil's BBQ",
#    'contact': {},
#    'location': {'address': '9816 Mission Gorge Rd',
#     'lat': 32.840576575013955,
#     'lng': -116.9833485278995,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 32.840576575013955,
#       'lng': -116.9833485278995}],
#     'postalCode': '92071',
#     'cc': 'US',
#     'city': 'Santee',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['9816 Mission Gorge Rd',
#      'Santee, CA 92071',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1df931735',
#      'name': 'BBQ Joint',
#      'pluralName': 'BBQ Joints',
#      'shortName': 'BBQ',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#       'suffix': '.png'},
#      'primary': True}],
#    'verified': False,
#    'stats': {'tipCount': 0,
#     'usersCount': 0,
#     'checkinsCount': 0,
#     'visitsCount': 0},
#    'beenHere': {'count': 0,
#     'lastCheckinExpiredAt': 0,
#     'marked': False,
#     'unconfirmedCount': 0},
#    'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#    'referralId': 'v-1574440731',
#    'venueChains': [],
#    'hasPerk': False},
#   {'id': '4a836510f964a52004fb1fe3',
#    'name': 'The Spot',
#    'contact': {},
#    'location': {'address': '1005 Prospect St',
#     'crossStreet': 'at Girard Ave',
#     'lat': 32.84745492346954,
#     'lng': -117.27455687246737,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 32.84745492346954,
#       'lng': -117.27455687246737}],
#     'postalCode': '92037',
#     'cc': 'US',
#     'city': 'La Jolla',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['1005 Prospect St (at Girard Ave)',
#      'La Jolla, CA 92037',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d116941735',
#      'name': 'Bar',
#      'pluralName': 'Bars',
#      'shortName': 'Bar',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#       'suffix': '.png'},
#      'primary': True}],
#    'verified': False,
#    'stats': {'tipCount': 0,
#     'usersCount': 0,
#     'checkinsCount': 0,
#     'visitsCount': 0},
#    'beenHere': {'count': 0,
#     'lastCheckinExpiredAt': 0,
#     'marked': False,
#     'unconfirmedCount': 0},
#    'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#    'referralId': 'v-1574440731',
#    'venueChains': [],
#    'hasPerk': False},
#   {'id': '4e078f4eb0fbba5eee1d0560',
#    'name': "Mike's BBQ",
#    'contact': {},
#    'location': {'address': '1356 W Valley Pkwy',
#     'lat': 33.11191590783339,
#     'lng': -117.10416144415515,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 33.11191590783339,
#       'lng': -117.10416144415515}],
#     'postalCode': '92029',
#     'cc': 'US',
#     'city': 'Escondido',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['1356 W Valley Pkwy',
#      'Escondido, CA 92029',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1df931735',
#      'name': 'BBQ Joint',
#      'pluralName': 'BBQ Joints',
#      'shortName': 'BBQ',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#       'suffix': '.png'},
#      'primary': True}],
#    'verified': True,
#    'stats': {'tipCount': 0,
#     'usersCount': 0,
#     'checkinsCount': 0,
#     'visitsCount': 0},
#    'beenHere': {'count': 0,
#     'lastCheckinExpiredAt': 0,
#     'marked': False,
#     'unconfirmedCount': 0},
#    'venuePage': {'id': '43636000'},
#    'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#    'referralId': 'v-1574440731',
#    'venueChains': [],
#    'hasPerk': False},
#   {'id': '4c0c4805a1b32d7f3e659cf0',
#    'name': 'West Coast BBQ and Brew',
#    'contact': {},
#    'location': {'address': '6126 Lake Murray Blvd',
#     'lat': 32.790949030093515,
#     'lng': -117.02143280185798,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 32.790949030093515,
#       'lng': -117.02143280185798}],
#     'postalCode': '91942',
#     'cc': 'US',
#     'city': 'La Mesa',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['6126 Lake Murray Blvd',
#      'La Mesa, CA 91942',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1df931735',
#      'name': 'BBQ Joint',
#      'pluralName': 'BBQ Joints',
#      'shortName': 'BBQ',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#       'suffix': '.png'},
#      'primary': True}],
#    'verified': True,
#    'stats': {'tipCount': 0,
#     'usersCount': 0,
#     'checkinsCount': 0,
#     'visitsCount': 0},
#    'beenHere': {'count': 0,
#     'lastCheckinExpiredAt': 0,
#     'marked': False,
#     'unconfirmedCount': 0},
#    'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#    'referralId': 'v-1574440731',
#    'venueChains': [],
#    'hasPerk': False},
#   {'id': '4fdc1081e4b0b4dd28be2c98',
#    'name': 'Kogi BBQ',
#    'contact': {},
#    'location': {'address': '5447 Kearny Villa Rd',
#     'lat': 32.832826846316415,
#     'lng': -117.13835186622883,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 32.832826846316415,
#       'lng': -117.13835186622883}],
#     'postalCode': '92123',
#     'cc': 'US',
#     'city': 'San Diego',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['5447 Kearny Villa Rd',
#      'San Diego, CA 92123',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d113941735',
#      'name': 'Korean Restaurant',
#      'pluralName': 'Korean Restaurants',
#      'shortName': 'Korean',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/korean_',
#       'suffix': '.png'},
#      'primary': True}],
#    'verified': False,
#    'stats': {'tipCount': 0,
#     'usersCount': 0,
#     'checkinsCount': 0,
#     'visitsCount': 0},
#    'beenHere': {'count': 0,
#     'lastCheckinExpiredAt': 0,
#     'marked': False,
#     'unconfirmedCount': 0},
#    'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#    'referralId': 'v-1574440731',
#    'venueChains': [],
#    'hasPerk': False},
#   {'id': '5474e871498efe80cf40b0b6',
#    'name': 'Manna BBQ',
#    'contact': {},
#    'location': {'address': '8188 Mira Mesa Blvd',
#     'lat': 32.913087651676605,
#     'lng': -117.14773611937966,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 32.913087651676605,
#       'lng': -117.14773611937966}],
#     'postalCode': '92126',
#     'cc': 'US',
#     'neighborhood': 'Mira Mesa',
#     'city': 'San Diego',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['8188 Mira Mesa Blvd',
#      'San Diego, CA 92126',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d113941735',
#      'name': 'Korean Restaurant',
#      'pluralName': 'Korean Restaurants',
#      'shortName': 'Korean',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/korean_',
#       'suffix': '.png'},
#      'primary': True}],
#    'verified': False,
#    'stats': {'tipCount': 0,
#     'usersCount': 0,
#     'checkinsCount': 0,
#     'visitsCount': 0},
#    'beenHere': {'count': 0,
#     'lastCheckinExpiredAt': 0,
#     'marked': False,
#     'unconfirmedCount': 0},
#    'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#    'referralId': 'v-1574440731',
#    'venueChains': [],
#    'hasPerk': False},
#   {'id': '52b17b66498eeab2c01f23f1',
#    'name': 'Gyu-Kaku Japanese BBQ',
#    'contact': {},
#    'location': {'address': '9844 Hibert St Ste G-1',
#     'lat': 32.91489994841389,
#     'lng': -117.11408912565088,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 32.91489994841389,
#       'lng': -117.11408912565088}],
#     'postalCode': '92131',
#     'cc': 'US',
#     'city': 'San Diego',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['9844 Hibert St Ste G-1',
#      'San Diego, CA 92131',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1df931735',
#      'name': 'BBQ Joint',
#      'pluralName': 'BBQ Joints',
#      'shortName': 'BBQ',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#       'suffix': '.png'},
#      'primary': True}],
#    'verified': True,
#    'stats': {'tipCount': 0,
#     'usersCount': 0,
#     'checkinsCount': 0,
#     'visitsCount': 0},
#    'beenHere': {'count': 0,
#     'lastCheckinExpiredAt': 0,
#     'marked': False,
#     'unconfirmedCount': 0},
#    'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#    'referralId': 'v-1574440731',
#    'venueChains': [],
#    'hasPerk': False},
#   {'id': '572a5d9ecd105e31e87c7034',
#    'name': "Carnitas' Snack Shack - Embarcadero",
#    'contact': {},
#    'location': {'address': '1004 N Harbor Dr',
#     'lat': 32.716212492353684,
#     'lng': -117.17325853410645,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 32.716212492353684,
#       'lng': -117.17325853410645}],
#     'postalCode': '92101',
#     'cc': 'US',
#     'neighborhood': 'Marina',
#     'city': 'San Diego',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['1004 N Harbor Dr',
#      'San Diego, CA 92101',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1df931735',
#      'name': 'BBQ Joint',
#      'pluralName': 'BBQ Joints',
#      'shortName': 'BBQ',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#       'suffix': '.png'},
#      'primary': True}],
#    'verified': False,
#    'stats': {'tipCount': 0,
#     'usersCount': 0,
#     'checkinsCount': 0,
#     'visitsCount': 0},
#    'delivery': {'id': '1431599',
#     'url': 'https://www.grubhub.com/restaurant/carnitas-snack-shack-1004-n-harbor-dr-san-diego/1431599?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1431599',
#     'provider': {'name': 'grubhub',
#      'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#       'sizes': [40, 50],
#       'name': '/delivery_provider_grubhub_20180129.png'}}},
#    'beenHere': {'count': 0,
#     'lastCheckinExpiredAt': 0,
#     'marked': False,
#     'unconfirmedCount': 0},
#    'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#    'referralId': 'v-1574440731',
#    'venueChains': [],
#    'hasPerk': False},
#   {'id': '566b3764498e25d72e3a6bb3',
#    'name': "BT's Southern BBQ",
#    'contact': {},
#    'location': {'address': '7845 Highland Village Pl # C101',
#     'crossStreet': 'Via Francesco',
#     'lat': 32.96200817645033,
#     'lng': -117.1542094760459,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 32.96200817645033,
#       'lng': -117.1542094760459}],
#     'postalCode': '92129',
#     'cc': 'US',
#     'city': 'San Diego',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['7845 Highland Village Pl # C101 (Via Francesco)',
#      'San Diego, CA 92129',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1df931735',
#      'name': 'BBQ Joint',
#      'pluralName': 'BBQ Joints',
#      'shortName': 'BBQ',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#       'suffix': '.png'},
#      'primary': True}],
#    'verified': False,
#    'stats': {'tipCount': 0,
#     'usersCount': 0,
#     'checkinsCount': 0,
#     'visitsCount': 0},
#    'delivery': {'id': '345737',
#     'url': 'https://www.grubhub.com/restaurant/bts-southern-bbq-7845-highlands-village-pl-ste-c-101-san-diego/345737?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=345737',
#     'provider': {'name': 'grubhub',
#      'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#       'sizes': [40, 50],
#       'name': '/delivery_provider_grubhub_20180129.png'}}},
#    'beenHere': {'count': 0,
#     'lastCheckinExpiredAt': 0,
#     'marked': False,
#     'unconfirmedCount': 0},
#    'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#    'referralId': 'v-1574440731',
#    'venueChains': [],
#    'hasPerk': False},
#   {'id': '40e0b100f964a52051021fe3',
#    'name': 'Kansas City Barbeque',
#    'contact': {},
#    'location': {'address': '600 W Harbor Dr',
#     'lat': 32.71155894618459,
#     'lng': -117.16864228248596,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 32.71155894618459,
#       'lng': -117.16864228248596}],
#     'postalCode': '92101',
#     'cc': 'US',
#     'city': 'San Diego',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['600 W Harbor Dr',
#      'San Diego, CA 92101',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1df931735',
#      'name': 'BBQ Joint',
#      'pluralName': 'BBQ Joints',
#      'shortName': 'BBQ',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#       'suffix': '.png'},
#      'primary': True}],
#    'verified': True,
#    'stats': {'tipCount': 0,
#     'usersCount': 0,
#     'checkinsCount': 0,
#     'visitsCount': 0},
#    'beenHere': {'count': 0,
#     'lastCheckinExpiredAt': 0,
#     'marked': False,
#     'unconfirmedCount': 0},
#    'venuePage': {'id': '187730990'},
#    'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#    'referralId': 'v-1574440731',
#    'venueChains': [],
#    'hasPerk': False},
#   {'id': '52071b7b11d2dfe8a4be8a1b',
#    'name': 'Cheers Bar & Grill',
#    'contact': {},
#    'location': {'address': '9995 Carmel Mountain Rd Ste B1',
#     'crossStreet': 'Rancho Penasquitos Blvd',
#     'lat': 32.95989377534602,
#     'lng': -117.11221859951345,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 32.95989377534602,
#       'lng': -117.11221859951345}],
#     'postalCode': '92129',
#     'cc': 'US',
#     'city': 'San Diego',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['9995 Carmel Mountain Rd Ste B1 (Rancho Penasquitos Blvd)',
#      'San Diego, CA 92129',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d116941735',
#      'name': 'Bar',
#      'pluralName': 'Bars',
#      'shortName': 'Bar',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#       'suffix': '.png'},
#      'primary': True}],
#    'verified': False,
#    'stats': {'tipCount': 0,
#     'usersCount': 0,
#     'checkinsCount': 0,
#     'visitsCount': 0},
#    'beenHere': {'count': 0,
#     'lastCheckinExpiredAt': 0,
#     'marked': False,
#     'unconfirmedCount': 0},
#    'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#    'referralId': 'v-1574440731',
#    'venueChains': [],
#    'hasPerk': False},
#   {'id': '5cf96e7d1acf11002c15294f',
#    'name': 'Ranchwood BBQ',
#    'contact': {},
#    'location': {'address': '2533 Folex Way',
#     'lat': 32.72718,
#     'lng': -116.965694,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 32.72718,
#       'lng': -116.965694}],
#     'postalCode': '91978',
#     'cc': 'US',
#     'city': 'Spring Valley',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['2533 Folex Way',
#      'Spring Valley, CA 91978',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1df931735',
#      'name': 'BBQ Joint',
#      'pluralName': 'BBQ Joints',
#      'shortName': 'BBQ',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#       'suffix': '.png'},
#      'primary': True}],
#    'verified': False,
#    'stats': {'tipCount': 0,
#     'usersCount': 0,
#     'checkinsCount': 0,
#     'visitsCount': 0},
#    'delivery': {'id': '789173',
#     'url': 'https://www.grubhub.com/restaurant/ranchwood-bbq--catering-2533-folex-way-spring-valley/789173?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=789173',
#     'provider': {'name': 'grubhub',
#      'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#       'sizes': [40, 50],
#       'name': '/delivery_provider_grubhub_20180129.png'}}},
#    'beenHere': {'count': 0,
#     'lastCheckinExpiredAt': 0,
#     'marked': False,
#     'unconfirmedCount': 0},
#    'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#    'referralId': 'v-1574440731',
#    'venueChains': [],
#    'hasPerk': False},
#   {'id': '56ef801d498e353289c0b8a7',
#    'name': 'Tacos Kike',
#    'contact': {},
#    'location': {'address': 'Panamericano',
#     'lat': 32.467143197050405,
#     'lng': -117.01236006774145,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 32.467143197050405,
#       'lng': -117.01236006774145}],
#     'cc': 'MX',
#     'city': 'Tijuana',
#     'state': 'Baja California',
#     'country': 'México',
#     'formattedAddress': ['Panamericano',
#      'Tijuana, Baja California',
#      'México']},
#    'categories': [{'id': '4bf58dd8d48988d1df931735',
#      'name': 'BBQ Joint',
#      'pluralName': 'BBQ Joints',
#      'shortName': 'BBQ',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#       'suffix': '.png'},
#      'primary': True}],
#    'verified': False,
#    'stats': {'tipCount': 0,
#     'usersCount': 0,
#     'checkinsCount': 0,
#     'visitsCount': 0},
#    'beenHere': {'count': 0,
#     'lastCheckinExpiredAt': 0,
#     'marked': False,
#     'unconfirmedCount': 0},
#    'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#    'referralId': 'v-1574440731',
#    'venueChains': [],
#    'hasPerk': False},
#   {'id': '4abd4e23f964a520a08920e3',
#    'name': "Bubba's Smokehouse",
#    'contact': {},
#    'location': {'address': '888 Prospect St',
#     'crossStreet': 'at Fay Ave',
#     'lat': 32.846657,
#     'lng': -117.275795,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 32.846657,
#       'lng': -117.275795}],
#     'postalCode': '92037',
#     'cc': 'US',
#     'neighborhood': 'Village',
#     'city': 'La Jolla',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['888 Prospect St (at Fay Ave)',
#      'La Jolla, CA 92037',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1df931735',
#      'name': 'BBQ Joint',
#      'pluralName': 'BBQ Joints',
#      'shortName': 'BBQ',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#       'suffix': '.png'},
#      'primary': True}],
#    'verified': False,
#    'stats': {'tipCount': 0,
#     'usersCount': 0,
#     'checkinsCount': 0,
#     'visitsCount': 0},
#    'beenHere': {'count': 0,
#     'lastCheckinExpiredAt': 0,
#     'marked': False,
#     'unconfirmedCount': 0},
#    'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#    'referralId': 'v-1574440731',
#    'venueChains': [],
#    'hasPerk': False},
#   {'id': '40e0b100f964a520f3011fe3',
#    'name': 'Coaster Saloon',
#    'contact': {},
#    'location': {'address': '744 Ventura Pl',
#     'crossStreet': 'btwn Ocean Front Walk & Mission Blvd.',
#     'lat': 32.77211402646753,
#     'lng': -117.25180574511823,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 32.77211402646753,
#       'lng': -117.25180574511823}],
#     'postalCode': '92109',
#     'cc': 'US',
#     'city': 'San Diego',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['744 Ventura Pl (btwn Ocean Front Walk & Mission Blvd.)',
#      'San Diego, CA 92109',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d16c941735',
#      'name': 'Burger Joint',
#      'pluralName': 'Burger Joints',
#      'shortName': 'Burgers',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burger_',
#       'suffix': '.png'},
#      'primary': True}],
#    'verified': True,
#    'stats': {'tipCount': 0,
#     'usersCount': 0,
#     'checkinsCount': 0,
#     'visitsCount': 0},
#    'beenHere': {'count': 0,
#     'lastCheckinExpiredAt': 0,
#     'marked': False,
#     'unconfirmedCount': 0},
#    'venuePage': {'id': '461296831'},
#    'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#    'referralId': 'v-1574440731',
#    'venueChains': [],
#    'hasPerk': False},
#   {'id': '4bfc2322e05e0f470c40cfa8',
#    'name': 'Calypso Bay Smokehouse',
#    'contact': {},
#    'location': {'address': '500 Sea World Dr',
#     'crossStreet': 'SeaWorld San Diego',
#     'lat': 32.76585048561616,
#     'lng': -117.22465606980798,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 32.76585048561616,
#       'lng': -117.22465606980798}],
#     'postalCode': '92109',
#     'cc': 'US',
#     'city': 'San Diego',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['500 Sea World Dr (SeaWorld San Diego)',
#      'San Diego, CA 92109',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1df931735',
#      'name': 'BBQ Joint',
#      'pluralName': 'BBQ Joints',
#      'shortName': 'BBQ',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#       'suffix': '.png'},
#      'primary': True}],
#    'verified': False,
#    'stats': {'tipCount': 0,
#     'usersCount': 0,
#     'checkinsCount': 0,
#     'visitsCount': 0},
#    'beenHere': {'count': 0,
#     'lastCheckinExpiredAt': 0,
#     'marked': False,
#     'unconfirmedCount': 0},
#    'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#    'referralId': 'v-1574440731',
#    'venueChains': [],
#    'hasPerk': False},
#   {'id': '4b4d21e4f964a5201ccc26e3',
#    'name': "Bull's Smokin BBQ",
#    'contact': {},
#    'location': {'address': '1127 W Morena Blvd',
#     'lat': 32.76853788117238,
#     'lng': -117.20100254785041,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 32.76853788117238,
#       'lng': -117.20100254785041}],
#     'postalCode': '92110',
#     'cc': 'US',
#     'city': 'San Diego',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['1127 W Morena Blvd',
#      'San Diego, CA 92110',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1df931735',
#      'name': 'BBQ Joint',
#      'pluralName': 'BBQ Joints',
#      'shortName': 'BBQ',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#       'suffix': '.png'},
#      'primary': True}],
#    'verified': False,
#    'stats': {'tipCount': 0,
#     'usersCount': 0,
#     'checkinsCount': 0,
#     'visitsCount': 0},
#    'beenHere': {'count': 0,
#     'lastCheckinExpiredAt': 0,
#     'marked': False,
#     'unconfirmedCount': 0},
#    'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#    'referralId': 'v-1574440731',
#    'venueChains': [],
#    'hasPerk': False},
#   {'id': '4a9054fcf964a520551720e3',
#    'name': "Lil' Piggy's Bar-B-Q",
#    'contact': {},
#    'location': {'address': '1201 1st St',
#     'lat': 32.69882014707074,
#     'lng': -117.16983393235117,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 32.69882014707074,
#       'lng': -117.16983393235117}],
#     'postalCode': '92118',
#     'cc': 'US',
#     'city': 'Coronado',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['1201 1st St',
#      'Coronado, CA 92118',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1df931735',
#      'name': 'BBQ Joint',
#      'pluralName': 'BBQ Joints',
#      'shortName': 'BBQ',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#       'suffix': '.png'},
#      'primary': True}],
#    'verified': False,
#    'stats': {'tipCount': 0,
#     'usersCount': 0,
#     'checkinsCount': 0,
#     'visitsCount': 0},
#    'delivery': {'id': '985668',
#     'url': 'https://www.grubhub.com/restaurant/lil-piggys-barbq-1201-1st-st-coronado/985668?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=985668',
#     'provider': {'name': 'grubhub',
#      'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#       'sizes': [40, 50],
#       'name': '/delivery_provider_grubhub_20180129.png'}}},
#    'beenHere': {'count': 0,
#     'lastCheckinExpiredAt': 0,
#     'marked': False,
#     'unconfirmedCount': 0},
#    'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#    'referralId': 'v-1574440731',
#    'venueChains': [],
#    'hasPerk': False}],
#  'confident': False,
#  'geocode': {'what': '',
#   'where': 'san diego',
#   'feature': {'cc': 'US',
#    'name': 'San Diego',
#    'displayName': 'San Diego, CA, United States',
#    'matchedName': 'San Diego, CA, United States',
#    'highlightedName': '<b>San Diego</b>, CA, United States',
#    'woeType': 7,
#    'slug': 'san-diego-california',
#    'id': 'geonameid:5391811',
#    'longId': '72057594043319747',
#    'geometry': {'center': {'lat': 32.71533, 'lng': -117.15726},
#     'bounds': {'ne': {'lat': 33.114185, 'lng': -116.905723},
#      'sw': {'lat': 32.534870999999995, 'lng': -117.309797}}}},
#   'parents': []}}

# %% [markdown]
# #### Perfect! Now time to test you!
#
# Using `https://api.foursquare.com/v2/venues/explore` base url, set parameters based on the values [here](https://developer.foursquare.com/docs/api/venues/explore)
#
# After you get a JSON file you want, make a function and for loop to sort through the JSON file and make a pandas dataframe with the following columns.
# * Venue ID for the objects
# * Name of venue
# * Phone number
# * City
# * Venue URL for their website
#
# ##### Good luck!

# %%
## Your Code Here
